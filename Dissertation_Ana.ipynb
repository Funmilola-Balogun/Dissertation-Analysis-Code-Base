# %% [markdown]
# # PTSD Veterans Data Analysis

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Setup and Data Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Mount Google Drive

# %% [markdown]
# ### List Data Files

# %%
import os

data_path = '/content/drive/MyDrive/Colab Notebooks/Data set/'

if os.path.exists(data_path):
    print(f"Contents of '{data_path}':")
    for item in os.listdir(data_path):
        print(f"- {item}")
else:
    print(f"Error: The path '{data_path}' does not exist. Please verify the folder structure in your Google Drive and update 'data_path'.")
# Out:
# Contents of '/content/drive/MyDrive/Colab Notebooks/Data set/':
# - Harms_20250403.csv
# - PTSD_Dichotomous_Outcomes_Between_Arms_20250403.csv
# - PTSD_Continuous_Outcomes_Between_Arms_20250403.csv
# - PTSD_Dichotomous_Outcomes_Within_Arms_20250403.csv
# - Other_Outcomes_20250403.csv
# - PTSD_Continuous_Outcomes_Within_Arms_20250403.csv
# - Abbreviations_20250403.csv
# - Secondary_Studies_20250403.csv
# - Study_Interventions_20250403.csv
# - Study_Characteristics_20250403.csv
# - References_and_Study_Identifiers_20250403.csv
# - Sample_Characteristics_20250403.csv
# - Suicide_and_Self-harm_Continuous_Outcomes_-_Within_Arms_20250403.csv
# - Risk_Of_Bias_20250403.csv
# - Suicide_and_Self-harm_Continuous_Outcomes_-_Between_Arms_20250403.csv
# - Suicide_and_Self-harm_Dichotomous_Outcomes_-_Within_Arms_20250403.csv
# - Suicide_and_Self-harm_Dichotomous_Outcomes_-_Between_Arms_20250403.csv
# - histograms
# - Final_Veterans_PTSD_Dataset.csv
# - Final_Veterans_PTSD_Dataset_2.csv

# %% [markdown]
# ### Load CSV Files into DataFrames

# %%
csv_files = [f for f in os.listdir(data_path) if f.endswith('.csv')]

dataframes = {}

for filename in csv_files:
    file_path = os.path.join(data_path, filename)
    df_name = os.path.splitext(filename)[0] # Get filename without extension
    try:
        dataframes[df_name] = pd.read_csv(file_path)
        print(f"Successfully loaded '{filename}' as '{df_name}'")
    except Exception as e:
        print(f"Error loading '{filename}': {e}")

# Display the head of one of the loaded dataframes as an example
if 'Study_Interventions_20250403' in dataframes:
    print("\nDisplaying the first 5 rows of 'Study_Interventions_20250403':")
    display(dataframes['Study_Interventions_20250403'].head())
elif dataframes:
    # If 'Study_Interventions_20250403' is not there, pick the first one available
    first_df_name = next(iter(dataframes))
    print(f"\nDisplaying the first 5 rows of '{first_df_name}':")
    display(dataframes[first_df_name].head())
else:
    print("No CSV files were loaded.")
# Out:
# Successfully loaded 'Harms_20250403.csv' as 'Harms_20250403'
# Successfully loaded 'PTSD_Dichotomous_Outcomes_Between_Arms_20250403.csv' as 'PTSD_Dichotomous_Outcomes_Between_Arms_20250403'
# Successfully loaded 'PTSD_Continuous_Outcomes_Between_Arms_20250403.csv' as 'PTSD_Continuous_Outcomes_Between_Arms_20250403'
# Successfully loaded 'PTSD_Dichotomous_Outcomes_Within_Arms_20250403.csv' as 'PTSD_Dichotomous_Outcomes_Within_Arms_20250403'
# Successfully loaded 'Other_Outcomes_20250403.csv' as 'Other_Outcomes_20250403'
# Successfully loaded 'PTSD_Continuous_Outcomes_Within_Arms_20250403.csv' as 'PTSD_Continuous_Outcomes_Within_Arms_20250403'
# Successfully loaded 'Abbreviations_20250403.csv' as 'Abbreviations_20250403'
# Successfully loaded 'Secondary_Studies_20250403.csv' as 'Secondary_Studies_20250403'
# Successfully loaded 'Study_Interventions_20250403.csv' as 'Study_Interventions_20250403'
# Successfully loaded 'Study_Characteristics_20250403.csv' as 'Study_Characteristics_20250403'
# Successfully loaded 'References_and_Study_Identifiers_20250403.csv' as 'References_and_Study_Identifiers_20250403'
# Successfully loaded 'Sample_Characteristics_20250403.csv' as 'Sample_Characteristics_20250403'
# Successfully loaded 'Suicide_and_Self-harm_Continuous_Outcomes_-_Within_Arms_20250403.csv' as 'Suicide_and_Self-harm_Continuous_Outcomes_-_Within_Arms_20250403'
# Successfully loaded 'Risk_Of_Bias_20250403.csv' as 'Risk_Of_Bias_20250403'
# Successfully loaded 'Suicide_and_Self-harm_Continuous_Outcomes_-_Between_Arms_20250403.csv' as 'Suicide_and_Self-harm_Continuous_Outcomes_-_Between_Arms_20250403'
# Successfully loaded 'Suicide_and_Self-harm_Dichotomous_Outcomes_-_Within_Arms_20250403.csv' as 'Suicide_and_Self-harm_Dichotomous_Outcomes_-_Within_Arms_20250403'
# Successfully loaded 'Suicide_and_Self-harm_Dichotomous_Outcomes_-_Between_Arms_20250403.csv' as 'Suicide_and_Self-harm_Dichotomous_Outcomes_-_Between_Arms_20250403'
# Successfully loaded 'Final_Veterans_PTSD_Dataset.csv' as 'Final_Veterans_PTSD_Dataset'
# Successfully loaded 'Final_Veterans_PTSD_Dataset_2.csv' as 'Final_Veterans_PTSD_Dataset_2'
#
# Displaying the first 5 rows of 'Study_Interventions_20250403':
#          Study ID        Study Class  Study Publication Year  \
# 0  abdallah2022_A    Pharmacotherapy                    2022
# 1  abdallah2022_B    Pharmacotherapy                    2022
# 2  abdallah2022_C    Pharmacotherapy                    2022
# 3   abraham2022_A  Other study class                    2022
# 4   abraham2022_B  Other study class                    2022
#
#   Treatment Focus (Study level) Treatment Focus (Arm level)  \
# 0                          PTSD                        PTSD
# 1                          PTSD              Active Control
# 2                          PTSD            Inactive Control
# 3                          PTSD                        PTSD
# 4                          PTSD            Inactive Control
#
#   Treatment Focus Subclass (Arm level) Total N Randomized Intervention Group  \
# 0                                  NaN                158                  A
# 1                                  NaN                158                  B
# 2                                  NaN                158                  C
# 3                                  NaN                 29                  A
# 4                                  NaN                 29                  B
#
#    Arm N Randomized                            Arm N Randomized Detail  \
# 0              51.0  53 randomized, 2 excluded "never began" treatment
# 1              53.0  55 randomized, 2 excluded "never began" treatment
# 2              54.0  55 randomized, 1 excluded "never began" treatment
# 3              12.0                                                NaN
# 4              17.0                                                NaN
#
#                  Treatment Name Standardized Treatment Name  \
# 0        Standard dose ketamine                    Ketamine
# 1             Low dose ketamine                    Ketamine
# 2                       Placebo                     Placebo
# 3  Service dog training program             Animal Assisted
# 4                      Waitlist                    Waitlist
#
#                                Treatment Description Psychotherapy  \
# 0  Eight intravenous infusions of ketamine at a s...            No
# 1  Eight intravenous infusions of ketamine at a l...            No
# 2  Eight intravenous infusions of placebo (normal...            No
# 3  Participated in training service dogs for fell...            No
# 4                                           Waitlist            No
#
#   Psychotherapy Subclass Pharmacotherapy Pharmacotherapy Subclass CIH  \
# 0                    NaN             Yes    Other pharmacotherapy  No
# 1                    NaN             Yes    Other pharmacotherapy  No
# 2                    NaN              No                      NaN  No
# 3                    NaN              No                      NaN  No
# 4                    NaN              No                      NaN  No
#
#   CIH Subclass Nonpharmacologic Biologic Nonpharmacologic Cognitive Control  \
# 0          NaN                        No                         No      No
# 1          NaN                        No                         No     Yes
# 2          NaN                        No                         No     Yes
# 3          NaN                        No                         No      No
# 4          NaN                        No                         No     Yes
#
#   Other Collaborative Care      Format Delivery Method       Dose  \
# 0    No                 No  Individual       In Person  0.5 mg/kg
# 1    No                 No  Individual       In Person  0.2 mg/kg
# 2    No                 No  Individual       In Person        NaN
# 3   Yes                 No  Individual       In Person        NaN
# 4    No                 No         NaN             NaN        NaN
#
#   Session Length           Frequency Treatment Duration  \
# 0            NaN        Twice weekly                  4
# 1            NaN        Twice weekly                  4
# 2            NaN        Twice weekly                  4
# 3     60 minutes  Three times weekly                  2
# 4            NaN                 NaN                  2
#
#   Treatment Duration Detail Treatment Completion Definition  \
# 0                       NaN                             NaN
# 1                       NaN                             NaN
# 2                       NaN                             NaN
# 3   6 sessions over 2 weeks          Completed all sessions
# 4                       NaN                             NaN
#
#   Completed Psychotherapy Percent Completed Psychotherapy Percent Detail  \
# 0                             NaN                                    NaN
# 1                             NaN                                    NaN
# 2                             NaN                                    NaN
# 3                           83.33                                    NaN
# 4                             NaN                                    NaN
#
#   Treatment Adherence Definition  Adhered Pharmacotherapy Percent  \
# 0          completed 8 infusions                             63.0
# 1          completed 8 infusions                             72.0
# 2          completed 8 infusions                             81.0
# 3                            NaN                              NaN
# 4                            NaN                              NaN
#
#   Adhered Pharmacotherapy Percent Detail  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    Psychotherapy Sessions Completed Mean  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    Psychotherapy Sessions Completed Standard deviation  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Psychotherapy Sessions Completed Detail Dose at Study End Point Mean  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
# 2                                     NaN                          NaN
# 3                                     NaN                          NaN
# 4                                     NaN                          NaN
#
#   Dose at Study End Point Standard deviation Dose at Study End Point Detail  \
# 0                                        NaN                            NaN
# 1                                        NaN                            NaN
# 2                                        NaN                            NaN
# 3                                        NaN                            NaN
# 4                                        NaN                            NaN
#
#             Race/Ethnicity Reported Military Status (Study level)  \
# 0  Race and Ethnicity data reported                         Mixed
# 1  Race and Ethnicity data reported                         Mixed
# 2  Race and Ethnicity data reported                         Mixed
# 3  Race and Ethnicity data reported                         Mixed
# 4  Race and Ethnicity data reported                         Mixed
#
#    Active Duty Military Percent (Study level)  Veteran Percent (Study level)  \
# 0                                       32.28                          67.72
# 1                                       32.28                          67.72
# 2                                       32.28                          67.72
# 3                                         NaN                            NaN
# 4                                         NaN                            NaN
#
#    Community Percent (Study level)  Female Percent (Study level)  \
# 0                              0.0                         23.42
# 1                              0.0                         23.42
# 2                              0.0                         23.42
# 3                              0.0                         28.00
# 4                              0.0                         28.00
#
#    Male Percent (Study level) Trauma Type (Study level)  \
# 0                       76.58                       NaN
# 1                       76.58                       NaN
# 2                       76.58                       NaN
# 3                       72.00                       NaN
# 4                       72.00                       NaN
#
#   Trauma Detail (Study level) Risk of Bias Rating (Study level)  \
# 0                         NaN                              High
# 1                         NaN                              High
# 2                         NaN                              High
# 3                         NaN                              High
# 4                         NaN                              High
#
#                                             Citation  PTSDPubs ID  \
# 0  Abdallah CG, Roache JD, Gueorguieva R, et al. ...    1586306.0
# 1  Abdallah CG, Roache JD, Gueorguieva R, et al. ...    1586306.0
# 2  Abdallah CG, Roache JD, Gueorguieva R, et al. ...    1586306.0
# 3  Abraham PA, Kazman JB, Bonner JA, et al. Effec...    1620165.0
# 4  Abraham PA, Kazman JB, Bonner JA, et al. Effec...    1620165.0
#
#    Year Added to PTSD-Repository              Geocoded Point
# 0                           2023  POINT (-95.71289 37.09024)
# 1                           2023  POINT (-95.71289 37.09024)
# 2                           2023  POINT (-95.71289 37.09024)
# 3                           2023  POINT (-95.71289 37.09024)
# 4                           2023  POINT (-95.71289 37.09024)

# %% [markdown]
# ### Inspect DataFrame Columns

# %%
print("Binary:\n", dataframes['PTSD_Dichotomous_Outcomes_Between_Arms_20250403'].columns)
print("\nInterventions:\n", dataframes['Study_Interventions_20250403'].columns)
print("\nBaseline:\n", dataframes['Sample_Characteristics_20250403'].columns)
# Out:
# Binary:
#  Index(['Study ID', 'PTSDpubs ID', 'Analysis Type',
#        'Adjusted Variables in Statistical Analysis',
#        'Method for Handling Missing Data', 'Statistical Analysis Method',
#        'Comparison Arms Designation', 'Assessment Point',
#        'Diagnostic Change Definition Number', 'Diagnostic Change Definition',
#        'Diagnostic Change 1 Effect Size Detail',
#        'Diagnostic Change 1 Effect Size Type',
#        'Diagnostic Change 1 Effect Size',
#        'Diagnostic Change 1 Effect Size Type of Variance Measure',
#        'Diagnostic Change 1 Effect Size Variance Value or Lower Bound',
#        'Diagnostic Change 1 Effect Size Variance Upper Bound',
#        'Diagnostic Change 1 Effect Size p value',
#        'Clinically Meaningful Response Definition Number',
#        'Clinically Meaningful Response Definition',
#        'Clinically Meaningful Response 1 Effect Size Detail',
#        'Clinically Meaningful Response 1 Effect Size Type',
#        'Clinically Meaningful Response 1 Effect Size',
#        'Clinically Meaningful Response 1 Effect Size Type of Variance Measure',
#        'Clinically Meaningful Response 1 Effect Size Variance Value or Lower Bound',
#        'Clinically Meaningful Response 1 Effect Size Variance Upper Bound',
#        'Clinically Meaningful Response 1 Effect Size p value',
#        'Additional Data Reported', 'Additional Effect Size Data Reported',
#        'Unique Row Identifier'],
#       dtype='object')
#
# Interventions:
#  Index(['Study ID', 'Study Class', 'Study Publication Year',
#        'Treatment Focus (Study level)', 'Treatment Focus (Arm level)',
#        'Treatment Focus Subclass (Arm level)', 'Total N Randomized',
#        'Intervention Group', 'Arm N Randomized', 'Arm N Randomized Detail',
#        'Treatment Name', 'Standardized Treatment Name',
#        'Treatment Description', 'Psychotherapy', 'Psychotherapy Subclass',
#        'Pharmacotherapy', 'Pharmacotherapy Subclass', 'CIH', 'CIH Subclass',
#        'Nonpharmacologic Biologic', 'Nonpharmacologic Cognitive', 'Control',
#        'Other', 'Collaborative Care', 'Format', 'Delivery Method', 'Dose',
#        'Session Length', 'Frequency', 'Treatment Duration',
#        'Treatment Duration Detail', 'Treatment Completion Definition',
#        'Completed Psychotherapy Percent',
#        'Completed Psychotherapy Percent Detail',
#        'Treatment Adherence Definition', 'Adhered Pharmacotherapy Percent',
#        'Adhered Pharmacotherapy Percent Detail',
#        'Psychotherapy Sessions Completed Mean',
#        'Psychotherapy Sessions Completed Standard deviation',
#        'Psychotherapy Sessions Completed Detail',
#        'Dose at Study End Point Mean',
#        'Dose at Study End Point Standard deviation',
#        'Dose at Study End Point Detail', 'Race/Ethnicity Reported',
#        'Military Status (Study level)',
#        'Active Duty Military Percent (Study level)',
#        'Veteran Percent (Study level)', 'Community Percent (Study level)',
#        'Female Percent (Study level)', 'Male Percent (Study level)',
#        'Trauma Type (Study level)', 'Trauma Detail (Study level)',
#        'Risk of Bias Rating (Study level)', 'Citation', 'PTSDPubs ID',
#        'Year Added to PTSD-Repository', 'Geocoded Point'],
#       dtype='object')
#
# Baseline:
#  Index(['Study ID', 'Study Publication Year', 'Study Class',
#        'Treatment Focus (Study level)', 'N Randomized', 'N Randomized Detail',
#        'PTSD Criteria Met at Baseline Percent',
#        'PTSD Criteria Met at Baseline Percent Detail',
#        'PTSD Severity at Baseline Definition',
#        'PTSD Severity at Baseline Mean',
#        'PTSD Severity at Baseline Standard Deviation',
#        'PTSD Severity at Baseline Detail', 'Additional PTSD Severity Data',
#        'Duration of Symptoms/Diagnosis Mean',
#        'Duration of Symptoms/Diagnosis Standard Deviation',
#        'Duration of Symptoms/Diagnosis Detail', 'Active Duty Military Percent',
#        'Service-Connected Veteran Percent',
#        'Service-Connected Veteran Percent Detail', 'Veteran Percent',
#        'Community Percent', 'Military Status', 'Military Status Detail',
#        'Age Mean', 'Age Standard Deviation', 'Age Detail', 'Female Percent',
#        'Male Percent', 'Race/Ethnicity Reported', 'Race, White', 'Race, Black',
#        'Race, AIAN', 'Race, Asian', 'Race, NHPI', 'Race, Other',
#        'Race, Detail', 'Ethnicity, Hispanic', 'Ethnicity, Hispanic Detail',
#        'Percent Treatment-naive', 'Percent Treatment-naive Detail',
#        'Percent with Depression', 'Percent with Depression Detail',
#        'Percent with TBI History', 'Percent with TBI History Detail',
#        'Trauma Type', 'Trauma Detail', 'Trauma Types Mean',
#        'Trauma Types Standard Deviation', 'Trauma Types Detail',
#        'Trauma Events Mean', 'Trauma Events Standard Deviation',
#        'Trauma Events Detail', 'SUD Substance Class',
#        'SUD Specific Substance Target',
#        'Current SUD Inclusion/Exclusion Criteria',
#        'Percent With Any SUD Detail', 'Patients with Suicidality Excluded',
#        'Suicide or Self-Directed Violence Exclusion/Inclusion Criteria',
#        'Suicide or Self-Directed Violence Definition',
#        'Suicide or Self-Directed Violence Percent',
#        'Suicide or Self-Directed Violence Detail',
#        'Psychotic Disorder or Symptom Inclusion/Exclusion Criteria',
#        'Psychotic Disorder or Symptom Related Definition',
#        'Psychotic Disorder or Symptom Related Percent',
#        'Psychotic Disorder or Symptom Related Detail',
#        'Personality Disorder Definition', 'Personality Disorder Percent',
#        'Personality Disorder Detail', 'Anxiety Disorder Definition',
#        'Anxiety Disorder Percent', 'Anxiety Disorder Detail',
#        'Prior Inpatient Hospitalization Percent',
#        'Prior Inpatient Hospitalization Percent Detail', 'Geometric Point',
#        'Risk of Bias Rating', 'Citation', 'PTSDPubs ID',
#        'Year Added to PTSD-Repository'],
#       dtype='object')

# %% [markdown]
# ## Initial Data Preparation (Legacy/Refactored Steps)

# %%
df = dataframes['PTSD_Dichotomous_Outcomes_Between_Arms_20250403'].copy()

# %% [markdown]
# ### Initialize DataFrame for Between-Arm Outcomes

# %%
df['arm_id'] = df['Study ID'].astype(str) + "_" + df['Comparison Arms Designation'].astype(str)
display(df[['Study ID', 'Comparison Arms Designation', 'arm_id']].head())
# Out:
#           Study ID Comparison Arms Designation                    arm_id
# 0     abdallah2022                 A vs B vs C  abdallah2022_A vs B vs C
# 1     abdallah2022                 A vs B vs C  abdallah2022_A vs B vs C
# 2     acarturk2016                      A vs B       acarturk2016_A vs B
# 3     acarturk2016                      A vs B       acarturk2016_A vs B
# 4  ahmadizadeh2018                      A vs B    ahmadizadeh2018_A vs B

# %% [markdown]
# ### Prepare Study Characteristics

# %%
study_char = dataframes['Study_Characteristics_20250403']
features_char = study_char[[
    'Study ID',
    'Trauma Type',
    'Diagnostic Measure',
    'Clinical Setting',
    'Military Status'
]]
display(features_char.head())
# Out:
#                Study ID     Trauma Type Diagnostic Measure   Clinical Setting  \
# 0          alghamdi2015             NaN              SPTSS  Outpatient clinic
# 1      astillwright2023           Mixed                DSM  Outpatient clinic
# 2         blanchard2003       Accidents               CAPS  Outpatient clinic
# 3  boterhovendehaan2020           Mixed               SCID  Outpatient clinic
# 4              ford2018  Combat-related               CAPS  Outpatient clinic
#
#   Military Status
# 0       Community
# 1       Community
# 2       Community
# 3       Community
# 4           Mixed

# %% [markdown]
# ### Prepare Sample Characteristics

# %%
sample_char = dataframes['Sample_Characteristics_20250403']
features_demo = sample_char[[
    'Study ID',
    'Veteran Percent',
    'Female Percent',
    'Male Percent'
]]
display(features_demo.head())
# Out:
#        Study ID  Veteran Percent  Female Percent  Male Percent
# 0  abdallah2022            67.72           23.42         76.58
# 1   abraham2022              NaN           28.00         72.00
# 2  acarturk2016              NaN           74.49         25.51
# 3   acierno2017           100.00            3.79         96.21
# 4   acierno2021           100.00          100.00          0.00

# %% [markdown]
# ### Prepare Intervention Features

# %%
import pandas as pd

# 1. Use the already loaded interventions source file
interventions_df = dataframes['Study_Interventions_20250403'].copy()

# 2. Select the EXACT column names present in the source file
# Note: 'Treatment Duration' is the correct name for the duration field.
# Note: 'Intervention Group' is the correct name for the group/arm field.
features_int = interventions_df[[
    'Study ID',
    'Intervention Group',
    'Standardized Treatment Name',
    'Delivery Method',
    'Treatment Duration'
]].copy()

# 3. Standardise the column names for your master dataset
features_int.columns = [
    'Study ID',
    'Group',
    'Standardized Treatment Name',
    'Delivery Method',
    'duration_fixed'
]

# 4. Clean the keys to ensure a successful merge (stripping trailing spaces)
features_int['Study ID'] = features_int['Study ID'].astype(str).str.strip()
features_int['Group'] = features_int['Group'].astype(str).str.strip()

# 5. Convert duration to numeric (handling non-numeric 'Detail' text if present)
features_int['duration_fixed'] = pd.to_numeric(features_int['duration_fixed'], errors='coerce')

# 6. View the results to confirm
print("Intervention features successfully prepared.")
display(features_int.head())
# Out:
# Intervention features successfully prepared.
#          Study ID Group Standardized Treatment Name Delivery Method  \
# 0  abdallah2022_A     A                    Ketamine       In Person
# 1  abdallah2022_B     B                    Ketamine       In Person
# 2  abdallah2022_C     C                     Placebo       In Person
# 3   abraham2022_A     A             Animal Assisted       In Person
# 4   abraham2022_B     B                    Waitlist             NaN
#
#    duration_fixed
# 0             4.0
# 1             4.0
# 2             4.0
# 3             2.0
# 4             2.0

# %% [markdown]
# ### Merge Study and Arm-Level Data

# %%
# Study-level merges
df = df.merge(features_char, on='Study ID', how='left')
df = df.merge(features_demo, on='Study ID', how='left')

# Rename 'Comparison Arms Designation' in df to 'Group' to match features_int for merging
df.rename(columns={'Comparison Arms Designation': 'Group'}, inplace=True)

# Arm-level merge
df = df.merge(features_int, on=['Study ID', 'Group'], how='left')

# %% [markdown]
# ### Integrate Baseline Severity (First Attempt)

# %%
import pandas as pd

# 1. Load the specific source file for within-arm continuous outcomes
baseline_raw = dataframes['PTSD_Continuous_Outcomes_Within_Arms_20250403'].copy()

# 2. Filter strictly for 'Baseline' scores to avoid longitudinal duplicates
# Assessment Point 'Baseline' is the indicator for pre-treatment scores [1-3].
baseline_filtered = baseline_raw[baseline_raw['Assessment Point'] == 'Baseline'].copy()

# 3. FIX: Calculate the Global Median from the SOURCE data
# This ensures we get a real number (like 50 or 60) regardless of the merge success.
global_baseline_median = baseline_filtered['Measure Score Mean'].median()

# 4. Select required columns and standardise the names
# 'Intervention Group' in the source corresponds to 'Group' in your master dataset [1, 2].
baseline_features = baseline_filtered[['Study ID', 'Intervention Group', 'Measure Score Mean']].copy()
baseline_features.columns = ['Study ID', 'Group', 'baseline_severity']

# 5. Essential Cleanup: Strip spaces to ensure the merge finds matches
# Whitespace in IDs is a common cause for 'empty' columns after a merge.
baseline_features['Study ID'] = baseline_features['Study ID'].astype(str).str.strip()
baseline_features['Group'] = baseline_features['Group'].astype(str).str.strip()
df['Study ID'] = df['Study ID'].astype(str).str.strip()
df['Group'] = df['Group'].astype(str).str.strip()

# --- Debugging added: Check merge keys ---
print("\n--- Debugging Baseline Merge ---")
print(f"Unique (Study ID, Group) pairs in df: {df[['Study ID', 'Group']].drop_duplicates().shape[0]}")
print(f"Unique (Study ID, Group) pairs in baseline_features: {baseline_features[['Study ID', 'Group']].drop_duplicates().shape[0]}")

# Temporarily perform an inner merge to see how many rows would actually match
matched_rows = pd.merge(df[['Study ID', 'Group']].drop_duplicates(), baseline_features[['Study ID', 'Group']].drop_duplicates(), on=['Study ID', 'Group'], how='inner')
print(f"Number of (Study ID, Group) pairs that would match in an inner join: {matched_rows.shape[0]}")
print("----------------------------------")
# --- End Debugging ---

# Fix: Remove baseline_severity from df if it exists to avoid MergeError
if 'baseline_severity' in df.columns:
    df = df.drop(columns=['baseline_severity'])

# 6. Merge baseline severity into your comprehensive dataset (df)
df = df.merge(baseline_features, on=['Study ID', 'Group'], how='left')

# Add a check to ensure the 'baseline_severity' column exists after the merge
# This handles cases where the merge might unexpectedly fail to introduce the column.
if 'baseline_severity' not in df.columns:
    df['baseline_severity'] = pd.NA

# 7. Use the Global Median for imputation
# Now, if any veteran arms didn't match, they get the global average.
df['baseline_severity'] = df['baseline_severity'].fillna(global_baseline_median)

print(f"Baseline severity successfully integrated.")
print(f"Used Global Median for imputation: {global_baseline_median}")
print(df[['Study ID', 'Group', 'baseline_severity']].head())
# Out:
# --- Debugging Baseline Merge ---
# Unique (Study ID, Group) pairs in df: 295
# Unique (Study ID, Group) pairs in baseline_features: 1207
# Number of (Study ID, Group) pairs that would match in an inner join: 0
# ----------------------------------
# Baseline severity successfully integrated.
# Used Global Median for imputation: 54.67
#           Study ID        Group  baseline_severity
# 0     abdallah2022  A vs B vs C              54.67
# 1     abdallah2022  A vs B vs C              54.67
# 2     acarturk2016       A vs B              54.67
# 3     acarturk2016       A vs B              54.67
# 4  ahmadizadeh2018       A vs B              54.67

# %% [markdown]
# ### Integrate Continuous Outcomes (First Attempt)

# %%
# 1. Load the specific file containing continuous outcomes from the dataframes dictionary
outcomes_cont_raw = dataframes['PTSD_Continuous_Outcomes_Between_Arms_20250403'].copy()

# --- DEBUG: Print columns to identify the correct grouping column ---
# print("Columns in outcomes_cont_raw:")
# print(outcomes_cont_raw.columns)
# --- END DEBUG ---

# 2. Select the key columns
continuous_outcomes_features = outcomes_cont_raw[[
    'Study ID',
    'Arms Compared',  # Corrected column name
    'Score Difference 1',
    'EPC Calculated: Comparison Standardized Effect Size'
]].copy()

# 3. Rename columns for consistency and clarity
continuous_outcomes_features.rename(columns={
    'Arms Compared': 'Group',  # Renaming 'Arms Compared' to 'Group'
    'Score Difference 1': 'score_difference_1',
    'EPC Calculated: Comparison Standardized Effect Size': 'es_comparison'
}, inplace=True);

# 4. Handle potential conflicting columns before merging
# Identify columns in continuous_outcomes_features that are not merge keys
cols_to_merge = ['score_difference_1', 'es_comparison']

# Drop these columns and their potentially suffixed versions from df if they exist
for col in cols_to_merge:
    if col in df.columns:
        df = df.drop(columns=[col])
    if f'{col}_x' in df.columns: # Check for _x suffix from previous merges
        df = df.drop(columns=[f'{col}_x'])
    if f'{col}_y' in df.columns: # Check for _y suffix from previous merges
        df = df.drop(columns=[f'{col}_y'])

# 5. Merge into your existing comprehensive dataset (df)
df = df.merge(continuous_outcomes_features, on=['Study ID', 'Group'], how='left')

print("Continuous outcomes successfully integrated.")
# Display the head with the new columns to verify
print(df[['Study ID', 'Group', 'score_difference_1', 'es_comparison']].head())
# Out:
# Continuous outcomes successfully integrated.
#        Study ID        Group  score_difference_1  es_comparison
# 0  abdallah2022  A vs B vs C                 NaN            NaN
# 1  abdallah2022  A vs B vs C                 NaN            NaN
# 2  abdallah2022  A vs B vs C                 NaN            NaN
# 3  abdallah2022  A vs B vs C                 NaN            NaN
# 4  acarturk2016       A vs B                 NaN            NaN

# %% [markdown]
# ### Apply Veteran Filter (First Attempt)

# %%
df = df[
    (df['Veteran Percent'] > 0) |
    (df['Military Status'] == 'Veteran')
]

# %% [markdown]
# ### Integrate Binary Outcome (First Attempt)

# %%
import pandas as pd

# 1. Load the within-arm dichotomous outcomes file
# This file contains the 'Percent Achieved Diagnostic Change' column
dichot_within = dataframes['PTSD_Dichotomous_Outcomes_Within_Arms_20250403'].copy()

# 2. Filter for primary success at the End of Treatment
# Assessment Point '0' represents end-of-treatment results
# Diagnostic Change Definition Number 1 is typically the primary outcome
dichot_filtered = dichot_within[
    (dichot_within['Assessment Point'] == '0') &
    (dichot_within['Diagnostic Change Definition Number'] == 1)
].copy()

# 3. Standardise the keys and select the target column
# 'Intervention Group' in this file corresponds to 'Group' in your master dataset
dichot_subset = dichot_filtered[['Study ID', 'Intervention Group', 'Percent Achieved Diagnostic Change']].copy()
dichot_subset.columns = ['Study ID', 'Group', 'Percent Achieved Diagnostic Change']

# 4. Clean keys to ensure a perfect merge
dichot_subset['Study ID'] = dichot_subset['Study ID'].astype(str).str.strip()
dichot_subset['Group'] = dichot_subset['Group'].astype(str).str.strip()
df['Study ID'] = df['Study ID'].astype(str).str.strip()
df['Group'] = df['Group'].astype(str).str.strip()

# 5. Merge into your master DataFrame (df)
df = df.merge(dichot_subset, on=['Study ID', 'Group'], how='left')

# 6. Create the Binary Target for DCA
# Success (1) = 50% or more remission; Failure (0) = less than 50%
df['binary_outcome'] = (df['Percent Achieved Diagnostic Change'] >= 50).astype(int)

# 7. Fill missing binary outcomes with 0 (assuming failure if not reported as success)
df['binary_outcome'] = df['binary_outcome'].fillna(0).astype(int)

print("Binary target successfully created for Decision Curve Analysis.")
print(df[['Study ID', 'Group', 'Percent Achieved Diagnostic Change', 'binary_outcome']].head())
# Out:
# Binary target successfully created for Decision Curve Analysis.
#           Study ID        Group  Percent Achieved Diagnostic Change  \
# 0     abdallah2022  A vs B vs C                                 NaN
# 1     abdallah2022  A vs B vs C                                 NaN
# 2     abdallah2022  A vs B vs C                                 NaN
# 3     abdallah2022  A vs B vs C                                 NaN
# 4  ahmadizadeh2018       A vs B                                 NaN
#
#    binary_outcome
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %% [markdown]
# ### Feature Engineering (First Attempt)

# %%
# 1. Normalize baseline severity
# This creates a standardized z-score, allowing for a uniform comparison across
# different diagnostic measures like the CAPS and PCL [2, 3].
df['baseline_z'] = (
    df['baseline_severity'] - df['baseline_severity'].mean()
) / df['baseline_severity'].std()

# 2. Standardize treatment duration column name
# The repository identifies this feature as 'Treatment Duration' [1].
# We use 'duration_fixed' here, which was the standardized name from our merge step.
df['treatment_duration'] = df['duration_fixed']

# 3. Final Check
print("Feature engineering complete.")
print(df[['Study ID', 'baseline_severity', 'baseline_z', 'treatment_duration']].head())
# Out:
# Feature engineering complete.
#           Study ID  baseline_severity  baseline_z  treatment_duration
# 0     abdallah2022              54.67    0.006169                 NaN
# 1     abdallah2022              54.67    0.006169                 NaN
# 2     abdallah2022              54.67    0.006169                 NaN
# 3     abdallah2022              54.67    0.006169                 NaN
# 4  ahmadizadeh2018              54.67    0.006169                 NaN

# %% [markdown]
# ### Exploratory Data Analysis (EDA) on First Attempt Features

# %%
# 1. EDA for baseline_z
print("\nDistribution of baseline_z:")
print(df['baseline_z'].describe())

# 2. EDA for treatment_duration
print("\nDistribution of treatment_duration:")
print(df['treatment_duration'].describe())

# 3. EDA for binary_outcome
print("\nCounts for binary_outcome:")
print(df['binary_outcome'].value_counts())
# Out:
# Distribution of baseline_z:
# count    9.110000e+02
# mean     6.169451e-03
# std      2.603515e-17
# min      6.169451e-03
# 25%      6.169451e-03
# 50%      6.169451e-03
# 75%      6.169451e-03
# max      6.169451e-03
# Name: baseline_z, dtype: float64
#
# Distribution of treatment_duration:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: treatment_duration, dtype: float64
#
# Counts for binary_outcome:
# binary_outcome
# 0    911
# Name: count, dtype: int64

# %% [markdown]
# ### Debugging Intermediate Columns

# %%
# Debugging: Inspect intermediate columns to understand the issues

print("\nDistribution of baseline_severity (before z-scoring):")
print(df['baseline_severity'].describe())

print("\nDistribution of duration_fixed (before assigning to treatment_duration):")
print(df['duration_fixed'].describe())

print("\nDistribution of Percent Achieved Diagnostic Change (before creating binary_outcome):")
print(df['Percent Achieved Diagnostic Change'].describe())
print(df['Percent Achieved Diagnostic Change'].value_counts(dropna=False))
# Out:
# Distribution of baseline_severity (before z-scoring):
# count    9.110000e+02
# mean     5.467000e+01
# std      1.151712e-12
# min      5.467000e+01
# 25%      5.467000e+01
# 50%      5.467000e+01
# 75%      5.467000e+01
# max      5.467000e+01
# Name: baseline_severity, dtype: float64
#
# Distribution of duration_fixed (before assigning to treatment_duration):
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: duration_fixed, dtype: float64
#
# Distribution of Percent Achieved Diagnostic Change (before creating binary_outcome):
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Percent Achieved Diagnostic Change, dtype: float64
# Percent Achieved Diagnostic Change
# NaN    911
# Name: count, dtype: int64

# %% [markdown]
# ## Rebuilding Main DataFrame (Arm-Level Correction)

# %% [markdown]
# ## Rebuilding the Main DataFrame (df) to be Arm-Level
#
# To resolve the persistent merge mismatches, we are restructuring the primary `df` to represent individual intervention arms rather than comparisons between arms.
#
# This involves:
# 1.  Initializing `df` with arm-level data from `Study_Interventions_20250403`.
# 2.  Merging study-level characteristics (`features_char`, `features_demo`) into this new arm-level `df`.
# 3.  Re-integrating arm-level features (`baseline_severity`, `treatment_duration`, `binary_outcome`) which previously failed to merge correctly.
#
# This approach ensures that merge keys (`Study ID`, `Group`) are consistent across all merges, allowing for accurate feature engineering.

# %% [markdown]
# ### Initialize New Arm-Level DataFrame and Merge Study/Demographic Characteristics

# %%
import pandas as pd
import numpy as np

# 1. Initialize a new arm-level dataframe from Study_Interventions_20250403
# This table inherently represents individual intervention arms.
new_df = dataframes['Study_Interventions_20250403'].copy()

# Select the key columns for an arm-level base
new_df = new_df[[
    'Study ID', # This is 'abdallah2022_a' format from Study_Interventions_20250403
    'Intervention Group', # This is 'A' format from Study_Interventions_20250403
    'Standardized Treatment Name',
    'Delivery Method',
    'Treatment Duration'
]].copy()

# Rename the original 'Study ID' to 'arm_id' as it uniquely identifies each arm
new_df.rename(columns={'Study ID': 'arm_id'}, inplace=True)

# Create a new 'Study ID' column by stripping the arm suffix (e.g., 'abdallah2022_a' becomes 'abdallah2022')
# This new 'Study ID' will be used for merging with study-level characteristics (features_char, features_demo)
# and other arm-level data that uses the base study ID.
new_df['Study ID'] = new_df['arm_id'].apply(lambda x: '_'.join(x.split('_')[:-1]) if '_' in x else x)

# Rename 'Intervention Group' to 'Group' for consistency as this is the arm identifier within a study
new_df.rename(columns={'Intervention Group': 'Group'}, inplace=True)

# Clean all string ID columns
new_df['arm_id'] = new_df['arm_id'].astype(str).str.strip().str.lower()
new_df['Study ID'] = new_df['Study ID'].astype(str).str.strip().str.lower()
new_df['Group'] = new_df['Group'].astype(str).str.strip()

# Convert 'Treatment Duration' to numeric and fill NaNs
new_df['Treatment Duration'] = pd.to_numeric(new_df['Treatment Duration'], errors='coerce')
new_df['Treatment Duration'] = new_df['Treatment Duration'].fillna(new_df['Treatment Duration'].median())
new_df.rename(columns={'Treatment Duration': 'treatment_duration'}, inplace=True)

# 2. Re-merge study-level features (features_char, features_demo)
# Ensure merge keys are cleaned consistently for study-level dataframes
features_char_cleaned = features_char.copy()
features_char_cleaned['Study ID'] = features_char_cleaned['Study ID'].astype(str).str.strip().str.lower()

features_demo_cleaned = features_demo.copy()
features_demo_cleaned['Study ID'] = features_demo_cleaned['Study ID'].astype(str).str.strip().str.lower()

# Merge study-level characteristics using the new 'Study ID' column (base study ID)
new_df = new_df.merge(features_char_cleaned, on='Study ID', how='left')
new_df = new_df.merge(features_demo_cleaned, on='Study ID', how='left')

# Ensure all columns are unique at this point before final assignment to df
new_df = new_df.loc[:,~new_df.columns.duplicated()]

# Update the main df reference to this new arm-level dataframe
df = new_df.copy()

print("New arm-level dataframe (df) initialized and study/demo characteristics merged.")
print(df.head())
print("Columns in df after 263a7a0b:", df.columns.tolist())
# Out:
# New arm-level dataframe (df) initialized and study/demo characteristics merged.
#            arm_id Group Standardized Treatment Name Delivery Method  \
# 0  abdallah2022_a     A                    Ketamine       In Person
# 1  abdallah2022_b     B                    Ketamine       In Person
# 2  abdallah2022_c     C                     Placebo       In Person
# 3   abraham2022_a     A             Animal Assisted       In Person
# 4   abraham2022_b     B                    Waitlist             NaN
#
#    treatment_duration      Study ID Trauma Type Diagnostic Measure  \
# 0                 4.0  abdallah2022         NaN               CAPS
# 1                 4.0  abdallah2022         NaN               CAPS
# 2                 4.0  abdallah2022         NaN               CAPS
# 3                 2.0   abraham2022         NaN        PCL and DSM
# 4                 2.0   abraham2022         NaN        PCL and DSM
#
#     Clinical Setting Military Status  Veteran Percent  Female Percent  \
# 0  Outpatient clinic           Mixed            67.72           23.42
# 1  Outpatient clinic           Mixed            67.72           23.42
# 2  Outpatient clinic           Mixed            67.72           23.42
# 3  Outpatient clinic           Mixed              NaN           28.00
# 4  Outpatient clinic           Mixed              NaN           28.00
#
#    Male Percent
# 0         76.58
# 1         76.58
# 2         76.58
# 3         72.00
# 4         72.00
# Columns in df after 263a7a0b: ['arm_id', 'Group', 'Standardized Treatment Name', 'Delivery Method', 'treatment_duration', 'Study ID', 'Trauma Type', 'Diagnostic Measure', 'Clinical Setting', 'Military Status', 'Veteran Percent', 'Female Percent', 'Male Percent']

# %% [markdown]
# ### Re-integrate Baseline Severity and Z-Score

# %%
# 3. Re-integrate Baseline Severity (adapted from previous Step B)

# Load the source data for baseline severity
baseline_raw = dataframes['PTSD_Continuous_Outcomes_Within_Arms_20250403'].copy()
baseline_raw['Study ID'] = baseline_raw['Study ID'].astype(str).str.strip().str.lower()
baseline_raw['Intervention Group'] = baseline_raw['Intervention Group'].astype(str).str.strip()

# Filter strictly for 'Baseline' scores
baseline_filtered = baseline_raw[baseline_raw['Assessment Point'] == 'Baseline'].copy()
real_median_severity = baseline_filtered['Measure Score Mean'].median()

# Prepare subset for merging
baseline_sub = baseline_filtered[['Study ID', 'Intervention Group', 'Measure Score Mean']].copy()
baseline_sub.columns = ['Study ID', 'Group', 'baseline_severity']

# Drop baseline_severity if it exists in the new df to prevent merge errors
if 'baseline_severity' in df.columns:
    df = df.drop(columns=['baseline_severity'])

# Merge into the new arm-level df
df = df.merge(baseline_sub, on=['Study ID', 'Group'], how='left')
df['baseline_severity'] = df['baseline_severity'].fillna(real_median_severity)

# Recalculate baseline_z with the now varied baseline_severity
df['baseline_z'] = (df['baseline_severity'] - df['baseline_severity'].mean()) / df['baseline_severity'].std()

print("Baseline Severity and Z-Score re-integrated into new arm-level df.")
print(df[['Study ID', 'Group', 'baseline_severity', 'baseline_z']].head())
# Out:
# Baseline Severity and Z-Score re-integrated into new arm-level df.
#        Study ID Group  baseline_severity  baseline_z
# 0  abdallah2022     A               38.5   -0.797452
# 1  abdallah2022     A               47.5   -0.344943
# 2  abdallah2022     B               40.4   -0.701922
# 3  abdallah2022     B               46.6   -0.390194
# 4  abdallah2022     C               38.8   -0.782368

# %% [markdown]
# ### Re-integrate Binary Outcome (with Debugging)

# %%
# 4. Re-integrate Binary Outcome (adapted from previous Step C)

# Load the source data for dichotomous outcomes
dichot_within = dataframes['PTSD_Dichotomous_Outcomes_Within_Arms_20250403'].copy()
dichot_within['Study ID'] = dichot_within['Study ID'].astype(str).str.strip().str.lower()
dichot_within['Intervention Group'] = dichot_within['Intervention Group'].astype(str).str.strip()

# Filter for End of Treatment (Assessment Point '0') and primary diagnostic change
dichot_filtered = dichot_within[(
dichot_within['Assessment Point'] == '0') &
                                (dichot_within['Diagnostic Change Definition Number'] == 1)
                               ].copy()

dichot_sub = dichot_filtered[['Study ID', 'Intervention Group', 'Percent Achieved Diagnostic Change']].copy()
dichot_sub.columns = ['Study ID', 'Group', 'Percent Achieved Diagnostic Change']

# --- Debugging added: Check merge keys ---
print("\n--- Debugging Dichotomous Outcome Merge ---")
print(f"Unique (Study ID, Group) pairs in df: {df[['Study ID', 'Group']].drop_duplicates().shape[0]}")
print(f"Unique (Study ID, Group) pairs in dichot_sub: {dichot_sub[['Study ID', 'Group']].drop_duplicates().shape[0]}")

# Temporarily perform an inner merge to see how many rows would actually match
matched_dichot_rows = pd.merge(df[['Study ID', 'Group']].drop_duplicates(), dichot_sub[['Study ID', 'Group']].drop_duplicates(), on=['Study ID', 'Group'], how='inner')
print(f"Number of (Study ID, Group) pairs that would match in an inner join: {matched_dichot_rows.shape[0]}")
print("-------------------------------------------")
# --- End Debugging ---

# Drop existing columns if they exist to prevent merge errors
if 'Percent Achieved Diagnostic Change' in df.columns:
    df = df.drop(columns=['Percent Achieved Diagnostic Change'])
if 'binary_outcome' in df.columns:
    df = df.drop(columns=['binary_outcome'])

# Merge into the new arm-level df
df = df.merge(dichot_sub, on=['Study ID', 'Group'], how='left')

# Set the binary outcome with a 30% threshold
df['binary_outcome'] = (df['Percent Achieved Diagnostic Change'] >= 30).astype(int)

# Fill any remaining NaNs in binary_outcome with 0 (for arms that didn't have this metric)
df['binary_outcome'] = df['binary_outcome'].fillna(0).astype(int)

print(f"Binary Target re-integrated into new arm-level df. Success cases (1.0) at 30% threshold: {df['binary_outcome'].sum()}")
print(df[['Study ID', 'Group', 'Percent Achieved Diagnostic Change', 'binary_outcome']].head())
# Out:
# --- Debugging Dichotomous Outcome Merge ---
# Unique (Study ID, Group) pairs in df: 1210
# Unique (Study ID, Group) pairs in dichot_sub: 353
# Number of (Study ID, Group) pairs that would match in an inner join: 353
# -------------------------------------------
# Binary Target re-integrated into new arm-level df. Success cases (1.0) at 30% threshold: 587
#        Study ID Group  Percent Achieved Diagnostic Change  binary_outcome
# 0  abdallah2022     A                                 NaN               0
# 1  abdallah2022     A                                 NaN               0
# 2  abdallah2022     B                                 NaN               0
# 3  abdallah2022     B                                 NaN               0
# 4  abdallah2022     C                                 NaN               0

# %% [markdown]
# ### Final EDA on Restructured Arm-Level DataFrame (after initial correction)

# %%
# 5. Final EDA on the restructured arm-level df

print("\n--- Final EDA on Restructured Arm-Level DataFrame ---")

# Distribution of baseline_z
print("\nDistribution of baseline_z:")
print(df['baseline_z'].describe())

# Distribution of treatment_duration
print("\nDistribution of treatment_duration:")
print(df['treatment_duration'].describe())

# Counts for binary_outcome
print("\nCounts for binary_outcome:")
print(df['binary_outcome'].value_counts())
# Out:
# --- Final EDA on Restructured Arm-Level DataFrame ---
#
# Distribution of baseline_z:
# count    2392.000000
# mean       -0.013804
# std         0.994517
# min        -2.740225
# 25%        -0.701922
# 50%         0.015556
# 75%         0.589614
# max         3.767863
# Name: baseline_z, dtype: float64
#
# Distribution of treatment_duration:
# count    2392.000000
# mean        9.425088
# std         6.780104
# min         0.140000
# 25%         6.000000
# 50%         8.000000
# 75%        12.000000
# max        78.000000
# Name: treatment_duration, dtype: float64
#
# Counts for binary_outcome:
# binary_outcome
# 0    1805
# 1     587
# Name: count, dtype: int64

# %% [markdown]
# ### Re-integrate Binary Outcome (Second Debugging Pass)

# %%
# 4. Re-integrate Binary Outcome (adapted from previous Step C)

# Load the source data for dichotomous outcomes
dichot_within = dataframes['PTSD_Dichotomous_Outcomes_Within_Arms_20250403'].copy()
dichot_within['Study ID'] = dichot_within['Study ID'].astype(str).str.strip().str.lower()
dichot_within['Intervention Group'] = dichot_within['Intervention Group'].astype(str).str.strip()

# Filter for End of Treatment (Assessment Point '0') and primary diagnostic change
dichot_filtered = dichot_within[(
dichot_within['Assessment Point'] == '0') &
                                (dichot_within['Diagnostic Change Definition Number'] == 1)
                               ].copy()

dichot_sub = dichot_filtered[['Study ID', 'Intervention Group', 'Percent Achieved Diagnostic Change']].copy()
dichot_sub.columns = ['Study ID', 'Group', 'Percent Achieved Diagnostic Change']

# Drop existing columns if they exist to prevent merge errors
if 'Percent Achieved Diagnostic Change' in df.columns:
    df = df.drop(columns=['Percent Achieved Diagnostic Change'])
if 'binary_outcome' in df.columns:
    df = df.drop(columns=['binary_outcome'])

# Merge into the new arm-level df
df = df.merge(dichot_sub, on=['Study ID', 'Group'], how='left')

# Set the binary outcome with a 30% threshold
df['binary_outcome'] = (df['Percent Achieved Diagnostic Change'] >= 30).astype(int)

# Fill any remaining NaNs in binary_outcome with 0 (for arms that didn't have this metric)
df['binary_outcome'] = df['binary_outcome'].fillna(0).astype(int)

print(f"Binary Target re-integrated into new arm-level df. Success cases (1.0) at 30% threshold: {df['binary_outcome'].sum()}")
print(df[['Study ID', 'Group', 'Percent Achieved Diagnostic Change', 'binary_outcome']].head())
# Out:
# Binary Target re-integrated into new arm-level df. Success cases (1.0) at 30% threshold: 791
#        Study ID Group  Percent Achieved Diagnostic Change  binary_outcome
# 0  abdallah2022     A                                 NaN               0
# 1  abdallah2022     A                                 NaN               0
# 2  abdallah2022     B                                 NaN               0
# 3  abdallah2022     B                                 NaN               0
# 4  abdallah2022     C                                 NaN               0

# %% [markdown]
# ### Re-integrate Binary Outcome (Third Debugging Pass)

# %%
# 4. Re-integrate Binary Outcome (adapted from previous Step C)

# Load the source data for dichotomous outcomes
dichot_within = dataframes['PTSD_Dichotomous_Outcomes_Within_Arms_20250403'].copy()
dichot_within['Study ID'] = dichot_within['Study ID'].astype(str).str.strip().str.lower()
dichot_within['Intervention Group'] = dichot_within['Intervention Group'].astype(str).str.strip()

# Filter for End of Treatment (Assessment Point '0') and primary diagnostic change
dichot_filtered = dichot_within[(
dichot_within['Assessment Point'] == '0') &
                                (dichot_within['Diagnostic Change Definition Number'] == 1)
                               ].copy()

dichot_sub = dichot_filtered[['Study ID', 'Intervention Group', 'Percent Achieved Diagnostic Change']].copy()
dichot_sub.columns = ['Study ID', 'Group', 'Percent Achieved Diagnostic Change']

# --- Debugging added: Check merge keys ---
print("\n--- Debugging Dichotomous Outcome Merge ---")
print(f"Unique (Study ID, Group) pairs in df: {df[['Study ID', 'Group']].drop_duplicates().shape[0]}")
print(f"Unique (Study ID, Group) pairs in dichot_sub: {dichot_sub[['Study ID', 'Group']].drop_duplicates().shape[0]}")

# Temporarily perform an inner merge to see how many rows would actually match
matched_dichot_rows = pd.merge(df[['Study ID', 'Group']].drop_duplicates(), dichot_sub[['Study ID', 'Group']].drop_duplicates(), on=['Study ID', 'Group'], how='inner')
print(f"Number of (Study ID, Group) pairs that would match in an inner join: {matched_dichot_rows.shape[0]}")
print("-------------------------------------------")
# --- End Debugging ---

# Drop existing columns if they exist to prevent merge errors
if 'Percent Achieved Diagnostic Change' in df.columns:
    df = df.drop(columns=['Percent Achieved Diagnostic Change'])
if 'binary_outcome' in df.columns:
    df = df.drop(columns=['binary_outcome'])

# Merge into the new arm-level df
df = df.merge(dichot_sub, on=['Study ID', 'Group'], how='left')

# Set the binary outcome with a 30% threshold
df['binary_outcome'] = (df['Percent Achieved Diagnostic Change'] >= 30).astype(int)

# Fill any remaining NaNs in binary_outcome with 0 (for arms that didn't have this metric)
df['binary_outcome'] = df['binary_outcome'].fillna(0).astype(int)

print(f"Binary Target re-integrated into new arm-level df. Success cases (1.0) at 30% threshold: {df['binary_outcome'].sum()}")
print(df[['Study ID', 'Group', 'Percent Achieved Diagnostic Change', 'binary_outcome']].head())
# Out:
# --- Debugging Dichotomous Outcome Merge ---
# Unique (Study ID, Group) pairs in df: 1210
# Unique (Study ID, Group) pairs in dichot_sub: 353
# Number of (Study ID, Group) pairs that would match in an inner join: 353
# -------------------------------------------
# Binary Target re-integrated into new arm-level df. Success cases (1.0) at 30% threshold: 1221
#        Study ID Group  Percent Achieved Diagnostic Change  binary_outcome
# 0  abdallah2022     A                                 NaN               0
# 1  abdallah2022     A                                 NaN               0
# 2  abdallah2022     B                                 NaN               0
# 3  abdallah2022     B                                 NaN               0
# 4  abdallah2022     C                                 NaN               0

# %% [markdown]
# ### Final EDA on Restructured Arm-Level DataFrame (after second debugging pass)

# %%
# 5. Final EDA on the restructured arm-level df

print("\n--- Final EDA on Restructured Arm-Level DataFrame ---")

# Distribution of baseline_z
print("\nDistribution of baseline_z:")
print(df['baseline_z'].describe())

# Distribution of treatment_duration
print("\nDistribution of treatment_duration:")
print(df['treatment_duration'].describe())

# Counts for binary_outcome
print("\nCounts for binary_outcome:")
print(df['binary_outcome'].value_counts())
# Out:
# --- Final EDA on Restructured Arm-Level DataFrame ---
#
# Distribution of baseline_z:
# count    3460.000000
# mean       -0.091185
# std         0.968534
# min        -2.740225
# 25%        -0.882926
# 50%         0.015556
# 75%         0.534936
# max         3.767863
# Name: baseline_z, dtype: float64
#
# Distribution of treatment_duration:
# count    3460.000000
# mean        8.864789
# std         6.036383
# min         0.140000
# 25%         6.000000
# 50%         8.000000
# 75%        12.000000
# max        78.000000
# Name: treatment_duration, dtype: float64
#
# Counts for binary_outcome:
# binary_outcome
# 0    2239
# 1    1221
# Name: count, dtype: int64

# %% [markdown]
# ### Re-integrate Baseline Severity (Fourth Debugging Pass)

# %%
# 3. Re-integrate Baseline Severity (adapted from previous Step B)

# Load the source data for baseline severity
baseline_raw = dataframes['PTSD_Continuous_Outcomes_Within_Arms_20250403'].copy()
baseline_raw['Study ID'] = baseline_raw['Study ID'].astype(str).str.strip().str.lower()
baseline_raw['Intervention Group'] = baseline_raw['Intervention Group'].astype(str).str.strip()

# Filter strictly for 'Baseline' scores
baseline_filtered = baseline_raw[baseline_raw['Assessment Point'] == 'Baseline'].copy()
real_median_severity = baseline_filtered['Measure Score Mean'].median()

# Prepare subset for merging
baseline_sub = baseline_filtered[['Study ID', 'Intervention Group', 'Measure Score Mean']].copy()
baseline_sub.columns = ['Study ID', 'Group', 'baseline_severity']

# Drop baseline_severity if it exists in the new df to prevent merge errors
if 'baseline_severity' in df.columns:
    df = df.drop(columns=['baseline_severity'])

# Merge into the new arm-level df
df = df.merge(baseline_sub, on=['Study ID', 'Group'], how='left')
df['baseline_severity'] = df['baseline_severity'].fillna(real_median_severity)

# Recalculate baseline_z with the now varied baseline_severity
df['baseline_z'] = (df['baseline_severity'] - df['baseline_severity'].mean()) / df['baseline_severity'].std()

print("Baseline Severity and Z-Score re-integrated into new arm-level df.")
print(df[['Study ID', 'Group', 'baseline_severity', 'baseline_z']].head())
# Out:
# Baseline Severity and Z-Score re-integrated into new arm-level df.
#        Study ID Group  baseline_severity  baseline_z
# 0  abdallah2022     A               38.5   -0.741308
# 1  abdallah2022     A               47.5   -0.267623
# 2  abdallah2022     A               38.5   -0.741308
# 3  abdallah2022     A               47.5   -0.267623
# 4  abdallah2022     B               40.4   -0.641308

# %% [markdown]
# ### Re-integrate Binary Outcome (Fourth Debugging Pass)

# %%
# 4. Re-integrate Binary Outcome (adapted from previous Step C)

# Load the source data for dichotomous outcomes
dichot_within = dataframes['PTSD_Dichotomous_Outcomes_Within_Arms_20250403'].copy()
dichot_within['Study ID'] = dichot_within['Study ID'].astype(str).str.strip().str.lower()
dichot_within['Intervention Group'] = dichot_within['Intervention Group'].astype(str).str.strip()

# Filter for End of Treatment (Assessment Point '0') and primary diagnostic change
dichot_filtered = dichot_within[(
dichot_within['Assessment Point'] == '0') &
                                (dichot_within['Diagnostic Change Definition Number'] == 1)
                               ].copy()

dichot_sub = dichot_filtered[['Study ID', 'Intervention Group', 'Percent Achieved Diagnostic Change']].copy()
dichot_sub.columns = ['Study ID', 'Group', 'Percent Achieved Diagnostic Change']

# --- Debugging added: Check merge keys ---
print("\n--- Debugging Dichotomous Outcome Merge ---")
print(f"Unique (Study ID, Group) pairs in df: {df[['Study ID', 'Group']].drop_duplicates().shape[0]}")
print(f"Unique (Study ID, Group) pairs in dichot_sub: {dichot_sub[['Study ID', 'Group']].drop_duplicates().shape[0]}")

# Temporarily perform an inner merge to see how many rows would actually match
matched_dichot_rows = pd.merge(df[['Study ID', 'Group']].drop_duplicates(), dichot_sub[['Study ID', 'Group']].drop_duplicates(), on=['Study ID', 'Group'], how='inner')
print(f"Number of (Study ID, Group) pairs that would match in an inner join: {matched_dichot_rows.shape[0]}")

# Print unique combinations to identify discrepancies
print("\nUnique (Study ID, Group) in df (sample):")
print(df[['Study ID', 'Group']].drop_duplicates().head(20))
print("\nUnique (Study ID, Group) in dichot_sub (sample):")
print(dichot_sub[['Study ID', 'Group']].drop_duplicates().head(20))

print("-------------------------------------------")
# --- End Debugging ---

# Drop existing columns if they exist to prevent merge errors
if 'Percent Achieved Diagnostic Change' in df.columns:
    df = df.drop(columns=['Percent Achieved Diagnostic Change'])
if 'binary_outcome' in df.columns:
    df = df.drop(columns=['binary_outcome'])

# Merge into the new arm-level df
df = df.merge(dichot_sub, on=['Study ID', 'Group'], how='left')

# Set the binary outcome with a 30% threshold
df['binary_outcome'] = (df['Percent Achieved Diagnostic Change'] >= 30).astype(int)

# Fill any remaining NaNs in binary_outcome with 0 (for arms that didn't have this metric)
df['binary_outcome'] = df['binary_outcome'].fillna(0).astype(int)

print(f"Binary Target re-integrated into new arm-level df. Success cases (1.0) at 30% threshold: {df['binary_outcome'].sum()}")
print(df[['Study ID', 'Group', 'Percent Achieved Diagnostic Change', 'binary_outcome']].head())
# Out:
# --- Debugging Dichotomous Outcome Merge ---
# Unique (Study ID, Group) pairs in df: 1210
# Unique (Study ID, Group) pairs in dichot_sub: 353
# Number of (Study ID, Group) pairs that would match in an inner join: 353
#
# Unique (Study ID, Group) in df (sample):
#            Study ID Group
# 0      abdallah2022     A
# 4      abdallah2022     B
# 8      abdallah2022     C
# 12      abraham2022     A
# 13      abraham2022     B
# 14     acarturk2016     A
# 18     acarturk2016     B
# 22      acierno2017     A
# 26      acierno2017     B
# 30      acierno2021     A
# 46      acierno2021     B
# 55     adenauer2011     A
# 56     adenauer2011     B
# 57       ahmadi2015     A
# 58       ahmadi2015     B
# 59       ahmadi2015     C
# 60  ahmadizadeh2018     A
# 61  ahmadizadeh2018     B
# 62  ahmadizadeh2018     C
# 63  ahmadizadeh2019     A
#
# Unique (Study ID, Group) in dichot_sub (sample):
#             Study ID Group
# 0       acarturk2016     A
# 2       acarturk2016     B
# 9    ahmadizadeh2019     A
# 10   ahmadizadeh2019     B
# 11         allen2022     A
# 12         allen2022     B
# 13          alon2022     A
# 14          alon2022     B
# 15     angelakis2020     A
# 19     angelakis2020     B
# 23     angelakis2020     C
# 36  astillwright2023     A
# 38  astillwright2023     B
# 39          back2019     A
# 41          back2019     B
# 43          beck2009     A
# 45          beck2009     B
# 53     bellehsen2021     A
# 54     bellehsen2021     B
# 57        bisson2022     A
# -------------------------------------------
# Binary Target re-integrated into new arm-level df. Success cases (1.0) at 30% threshold: 6543
#        Study ID Group  Percent Achieved Diagnostic Change  binary_outcome
# 0  abdallah2022     A                                 NaN               0
# 1  abdallah2022     A                                 NaN               0
# 2  abdallah2022     A                                 NaN               0
# 3  abdallah2022     A                                 NaN               0
# 4  abdallah2022     B                                 NaN               0

# %% [markdown]
# ### Final EDA on Restructured Arm-Level DataFrame (after fourth debugging pass)

# %%
# 5. Final EDA on the restructured arm-level df

print("\n--- Final EDA on Restructured Arm-Level DataFrame ---")

# Distribution of baseline_z
print("\nDistribution of baseline_z:")
print(df['baseline_z'].describe())

# Distribution of treatment_duration
print("\nDistribution of treatment_duration:")
print(df['treatment_duration'].describe())

# Counts for binary_outcome
print("\nCounts for binary_outcome:")
print(df['binary_outcome'].value_counts())
# Out:
# --- Final EDA on Restructured Arm-Level DataFrame ---
#
# Distribution of baseline_z:
# count    15300.000000
# mean        -0.101534
# std          0.969608
# min         -2.774994
# 25%         -1.027098
# 50%          0.109745
# 75%          0.359351
# max          4.037643
# Name: baseline_z, dtype: float64
#
# Distribution of treatment_duration:
# count    15300.000000
# mean         7.828805
# std          5.139401
# min          0.140000
# 25%          6.000000
# 50%          8.000000
# 75%         10.000000
# max         78.000000
# Name: treatment_duration, dtype: float64
#
# Counts for binary_outcome:
# binary_outcome
# 0    8757
# 1    6543
# Name: count, dtype: int64

# %% [markdown]
# ### Re-integrate Baseline Severity (Fifth Debugging Pass)

# %%
# 3. Re-integrate Baseline Severity (adapted from previous Step B)

# Load the source data for baseline severity
baseline_raw = dataframes['PTSD_Continuous_Outcomes_Within_Arms_20250403'].copy()
baseline_raw['Study ID'] = baseline_raw['Study ID'].astype(str).str.strip().str.lower()
baseline_raw['Intervention Group'] = baseline_raw['Intervention Group'].astype(str).str.strip()

# Filter strictly for 'Baseline' scores
baseline_filtered = baseline_raw[baseline_raw['Assessment Point'] == 'Baseline'].copy()
real_median_severity = baseline_filtered['Measure Score Mean'].median()

# Prepare subset for merging
baseline_sub = baseline_filtered[['Study ID', 'Intervention Group', 'Measure Score Mean']].copy()
baseline_sub.columns = ['Study ID', 'Group', 'baseline_severity']

# Drop baseline_severity if it exists in the new df to prevent merge errors
if 'baseline_severity' in df.columns:
    df = df.drop(columns=['baseline_severity'])

# Merge into the new arm-level df
df = df.merge(baseline_sub, on=['Study ID', 'Group'], how='left')
df['baseline_severity'] = df['baseline_severity'].fillna(real_median_severity)

# Recalculate baseline_z with the now varied baseline_severity
df['baseline_z'] = (df['baseline_severity'] - df['baseline_severity'].mean()) / df['baseline_severity'].std()

print("Baseline Severity and Z-Score re-integrated into new arm-level df.")
print(df[['Study ID', 'Group', 'baseline_severity', 'baseline_z']].head())
# Out:
# Baseline Severity and Z-Score re-integrated into new arm-level df.
#        Study ID Group  baseline_severity  baseline_z
# 0  abdallah2022     A               38.5   -0.650437
# 1  abdallah2022     A               47.5   -0.166800
# 2  abdallah2022     A               38.5   -0.650437
# 3  abdallah2022     A               47.5   -0.166800
# 4  abdallah2022     A               38.5   -0.650437

# %% [markdown]
# ### Re-integrate Binary Outcome (Fifth Debugging Pass)

# %%
# 4. Re-integrate Binary Outcome (adapted from previous Step C)

# Load the source data for dichotomous outcomes
dichot_within = dataframes['PTSD_Dichotomous_Outcomes_Within_Arms_20250403'].copy()
dichot_within['Study ID'] = dichot_within['Study ID'].astype(str).str.strip().str.lower()
dichot_within['Intervention Group'] = dichot_within['Intervention Group'].astype(str).str.strip()

# Filter for End of Treatment (Assessment Point '0') and primary diagnostic change
dichot_filtered = dichot_within[(
dichot_within['Assessment Point'] == '0') &
                                (dichot_within['Diagnostic Change Definition Number'] == 1)
                               ].copy()

dichot_sub = dichot_filtered[['Study ID', 'Intervention Group', 'Percent Achieved Diagnostic Change']].copy()
dichot_sub.columns = ['Study ID', 'Group', 'Percent Achieved Diagnostic Change']

# Drop existing columns if they exist to prevent merge errors
if 'Percent Achieved Diagnostic Change' in df.columns:
    df = df.drop(columns=['Percent Achieved Diagnostic Change'])
if 'binary_outcome' in df.columns:
    df = df.drop(columns=['binary_outcome'])

# Merge into the new arm-level df
df = df.merge(dichot_sub, on=['Study ID', 'Group'], how='left')

# Set the binary outcome with a 30% threshold
df['binary_outcome'] = (df['Percent Achieved Diagnostic Change'] >= 30).astype(int)

# Fill any remaining NaNs in binary_outcome with 0 (for arms that didn't have this metric)
df['binary_outcome'] = df['binary_outcome'].fillna(0).astype(int)

print(f"Binary Target re-integrated into new arm-level df. Success cases (1.0) at 30% threshold: {df['binary_outcome'].sum()}")
print(df[['Study ID', 'Group', 'Percent Achieved Diagnostic Change', 'binary_outcome']].head())
# Out:
# Binary Target re-integrated into new arm-level df. Success cases (1.0) at 30% threshold: 50259
#        Study ID Group  Percent Achieved Diagnostic Change  binary_outcome
# 0  abdallah2022     A                                 NaN               0
# 1  abdallah2022     A                                 NaN               0
# 2  abdallah2022     A                                 NaN               0
# 3  abdallah2022     A                                 NaN               0
# 4  abdallah2022     A                                 NaN               0

# %% [markdown]
# ### Final EDA on Restructured Arm-Level DataFrame (after fifth debugging pass)

# %%
# 5. Final EDA on the restructured arm-level df

print("\n--- Final EDA on Restructured Arm-Level DataFrame ---")

# Distribution of baseline_z
print("\nDistribution of baseline_z:")
print(df['baseline_z'].describe())

# Distribution of treatment_duration
print("\nDistribution of treatment_duration:")
print(df['treatment_duration'].describe())

# Counts for binary_outcome
print("\nCounts for binary_outcome:")
print(df['binary_outcome'].value_counts())
# Out:
# --- Final EDA on Restructured Arm-Level DataFrame ---
#
# Distribution of baseline_z:
# count    117766.000000
# mean         -0.125947
# std           0.947563
# min          -2.726850
# 25%          -1.177063
# 50%           0.218497
# 75%           0.256113
# max           4.228918
# Name: baseline_z, dtype: float64
#
# Distribution of treatment_duration:
# count    117766.000000
# mean          6.680866
# std           4.271932
# min           0.140000
# 25%           2.000000
# 50%           8.000000
# 75%           8.000000
# max          78.000000
# Name: treatment_duration, dtype: float64
#
# Counts for binary_outcome:
# binary_outcome
# 0    67507
# 1    50259
# Name: count, dtype: int64

# %% [markdown]
# ## Corrected Data Assembly Steps

# %% [markdown]
# ### Corrected Merge Keys and Treatment Duration

# %%
import pandas as pd
import numpy as np

# 1. Clean Master DF keys (ensure consistency for future merges)
df['Study ID'] = df['Study ID'].astype(str).str.strip().str.lower()
df['Group'] = df['Group'].astype(str).str.strip()

# 2. Fix Treatment Duration
# Use the already loaded dataframe from the dataframes dictionary
interventions = dataframes['Study_Interventions_20250403'].copy()
interventions['Study ID'] = interventions['Study ID'].astype(str).str.strip().str.lower()
interventions['Group'] = interventions['Intervention Group'].astype(str).str.strip()

# IMPORTANT FIX: Extract the base Study ID from interventions to match the main df's Study ID
interventions['base_study_id'] = interventions['Study ID'].apply(lambda x: '_'.join(x.split('_')[:-1]) if '_' in x else x)

# Select 'Treatment Duration' (the correct source name) using the new 'base_study_id'
duration_sub = interventions[['base_study_id', 'Group', 'Treatment Duration']].copy()
duration_sub.columns = ['Study ID', 'Group', 'treatment_duration']
duration_sub['treatment_duration'] = pd.to_numeric(duration_sub['treatment_duration'], errors='coerce')

# Drop treatment_duration from df if it exists to avoid merge conflicts and ensure a clean re-merge
if 'treatment_duration' in df.columns:
    df = df.drop(columns=['treatment_duration'])

# Merge using the corrected 'Study ID'
df = df.merge(duration_sub, on=['Study ID', 'Group'], how='left')

# Fill remaining NaNs. Use the global median of the original 'duration_sub' if the column is still all NaNs
# This ensures a value is used even if the merge completely failed for some reason.
global_median_duration = duration_sub['treatment_duration'].median()
df['treatment_duration'] = df['treatment_duration'].fillna(global_median_duration)

print("Step A: Corrected Merge Keys and Treatment Duration complete.")
# Out:
# Step A: Corrected Merge Keys and Treatment Duration complete.

# %% [markdown]
# ### Corrected Baseline Severity and Z-Score

# %%
# 1. Fix Baseline Severity and Z-Score
# Use the already loaded dataframe from the dataframes dictionary
baseline_raw = dataframes['PTSD_Continuous_Outcomes_Within_Arms_20250403'].copy()
baseline_raw['Study ID'] = baseline_raw['Study ID'].astype(str).str.strip().str.lower()
baseline_raw['Group'] = baseline_raw['Intervention Group'].astype(str).str.strip()

# Filter strictly for Baseline and calculate a real median from the source
baseline_filtered = baseline_raw[baseline_raw['Assessment Point'] == 'Baseline'].copy()
real_median_severity = baseline_filtered['Measure Score Mean'].median()

baseline_sub = baseline_filtered[['Study ID', 'Group', 'Measure Score Mean']].copy()
baseline_sub.columns = ['Study ID', 'Group', 'baseline_severity']

# Drop baseline_severity from df if it exists to avoid MergeError
if 'baseline_severity' in df.columns:
    df = df.drop(columns=['baseline_severity'])

# Merge and Re-Calculate Z-Score
df = df.merge(baseline_sub, on=['Study ID', 'Group'], how='left')
df['baseline_severity'] = df['baseline_severity'].fillna(real_median_severity)

# Now Z-score will have a standard deviation because baseline_severity has variation
df['baseline_z'] = (df['baseline_severity'] - df['baseline_severity'].mean()) / df['baseline_severity'].std()

print("Step B: Corrected Baseline Severity and Z-Score complete.")
# Out:
# Step B: Corrected Baseline Severity and Z-Score complete.

# %% [markdown]
# ### Adjusted Binary Target Threshold

# %%
# 1. Load Outcome Data
# Use the already loaded dataframe from the dataframes dictionary
dichot_within = dataframes['PTSD_Dichotomous_Outcomes_Within_Arms_20250403'].copy()
dichot_within['Study ID'] = dichot_within['Study ID'].astype(str).str.strip().str.lower()
dichot_within['Group'] = dichot_within['Intervention Group'].astype(str).str.strip()

# 2. Filter for End of Treatment (Assessment Point 0)
dichot_filtered = dichot_within[(dichot_within['Assessment Point'] == '0') &
                                (dichot_within['Diagnostic Change Definition Number'] == 1)].copy()

dichot_sub = dichot_filtered[['Study ID', 'Group', 'Percent Achieved Diagnostic Change']].copy()

# Drop 'Percent Achieved Diagnostic Change' and 'binary_outcome' if they exist to avoid MergeError
if 'Percent Achieved Diagnostic Change' in df.columns:
    df = df.drop(columns=['Percent Achieved Diagnostic Change'])
if 'binary_outcome' in df.columns:
    df = df.drop(columns=['binary_outcome'])

# 3. Merge and Set a Clinical Threshold of 50%
df = df.merge(dichot_sub, on=['Study ID', 'Group'], how='left')

# Use 50% as the new threshold for success
df['binary_outcome'] = (df['Percent Achieved Diagnostic Change'] >= 50).astype(int)

print(f"Step C: Adjusted Binary Target Threshold complete. Success cases (1.0) at 50% threshold: {df['binary_outcome'].sum()}")
# Out:
# Step C: Adjusted Binary Target Threshold complete. Success cases (1.0) at 50% threshold: 141692

# %% [markdown]
# ### Verify Binary Outcome Counts

# %%
print("Updated counts for binary_outcome with 50% threshold:")
print(df['binary_outcome'].value_counts())
# Out:
# Updated counts for binary_outcome with 50% threshold:
# binary_outcome
# 0    1140892
# 1     141692
# Name: count, dtype: int64

# %% [markdown]
# ### Check DataFrame Shape

# %%
print(df.shape)
# Out:
# (1282584, 17)

# %% [markdown]
# ### Reapply Veteran Filter

# %%
# Reapply the veteran filter to the current arm-level df
original_rows = df.shape[0]
df = df[
    (df['Veteran Percent'] > 0) |
    (df['Military Status'] == 'Veteran')
]
filtered_rows = df.shape[0]

print(f"Veteran filter reapplied. Original rows: {original_rows}, Filtered rows: {filtered_rows}")
print(f"Rows removed: {original_rows - filtered_rows}")
print("Current shape of df after re-applying veteran filter:", df.shape)
# Out:
# Veteran filter reapplied. Original rows: 1282584, Filtered rows: 99491
# Rows removed: 1183093
# Current shape of df after re-applying veteran filter: (99491, 17)

# %% [markdown]
# ### One-Hot Encode Categorical Features

# %%
df = pd.get_dummies(df, columns=[
    'Trauma Type',
    'Delivery Method',
    'Standardized Treatment Name'
])

# %% [markdown]
# ### Impute Missing Numerical Values

# %%
from sklearn.impute import SimpleImputer

num_cols = df.select_dtypes(include=np.number).columns

imputer = SimpleImputer(strategy='median')
df[num_cols] = imputer.fit_transform(df[num_cols])

# %% [markdown]
# ### Final Data Checks (Shape, Target Balance, Missing Values)

# %%
print("Shape:", df.shape)

print("\nTarget balance:")
print(df['binary_outcome'].value_counts())

print("\nMissing values:")
print(df.isnull().sum().sort_values(ascending=False).head(10))
# Out:
# Shape: (99491, 203)
#
# Target balance:
# binary_outcome
# 0.0    87642
# 1.0    11849
# Name: count, dtype: int64
#
# Missing values:
# arm_id                0
# Group                 0
# Study ID              0
# Diagnostic Measure    0
# Clinical Setting      0
# Military Status       0
# Veteran Percent       0
# Female Percent        0
# Male Percent          0
# baseline_z            0
# dtype: int64

# %% [markdown]
# ### Reapplying Veteran Filter (Duplicate Check - can be removed if intentional)

# %%
df = df[
    (df['Veteran Percent'] > 0) |
    (df['Military Status'] == 'Veteran')
]

# %% [markdown]
# ### Final Data Checks (After Duplicate Filter - can be removed if intentional)

# %%
print("Shape:", df.shape)

print("\nTarget balance:")
print(df['binary_outcome'].value_counts())

print("\nMissing values:")
print(df.isnull().sum().sort_values(ascending=False).head(10))
# Out:
# Shape: (99491, 203)
#
# Target balance:
# binary_outcome
# 0.0    87642
# 1.0    11849
# Name: count, dtype: int64
#
# Missing values:
# arm_id                0
# Group                 0
# Study ID              0
# Diagnostic Measure    0
# Clinical Setting      0
# Military Status       0
# Veteran Percent       0
# Female Percent        0
# Male Percent          0
# baseline_z            0
# dtype: int64

# %% [markdown]
# ### Export Final DataFrame (First Save)

# %%
output_path = data_path + 'Final_Veterans_PTSD_Dataset.csv'
df.to_csv(output_path, index=False)

print("Saved to:", output_path)
# Out:
# Saved to: /content/drive/MyDrive/Colab Notebooks/Data set/Final_Veterans_PTSD_Dataset.csv

# %% [markdown]
# ### Export Final DataFrame (Second Save - for reproducibility)

# %%
output_path_final = data_path + 'Final_Veterans_PTSD_Dataset_2.csv'
df.to_csv(output_path_final, index=False)

print(f"Final DataFrame saved to: {output_path_final}")
# Out:
# Final DataFrame saved to: /content/drive/MyDrive/Colab Notebooks/Data set/Final_Veterans_PTSD_Dataset_2.csv

# %% [markdown]
# ### Load and Verify Saved DataFrame

# %%
import pandas as pd

# Load the saved CSV file
output_path = data_path + 'Final_Veterans_PTSD_Dataset.csv'
loaded_df = pd.read_csv(output_path)

# Print all columns of the loaded DataFrame
print("Columns in the loaded CSV file:")
print(loaded_df.columns.tolist())

# Display the first few rows to confirm content
print("\nFirst 5 rows of the loaded DataFrame:")
display(loaded_df.head())
# Out:
# Columns in the loaded CSV file:
# ['arm_id', 'Group', 'Study ID', 'Diagnostic Measure', 'Clinical Setting', 'Military Status', 'Veteran Percent', 'Female Percent', 'Male Percent', 'baseline_z', 'treatment_duration', 'baseline_severity', 'Percent Achieved Diagnostic Change', 'binary_outcome', 'Trauma Type_Combat-related', 'Trauma Type_MST', 'Trauma Type_Mixed', 'Trauma Type_Other', 'Delivery Method_In Person', 'Delivery Method_In person', 'Delivery Method_Mixed', 'Delivery Method_Phone', 'Delivery Method_Technology Alone', 'Delivery Method_Technology Assisted', 'Delivery Method_Technology alone', 'Delivery Method_Technology assisted', 'Delivery Method_Video', 'Delivery Method_Written', 'Standardized Treatment Name_Accelerated Resolution Therapy (ART)', 'Standardized Treatment Name_Acupuncture', 'Standardized Treatment Name_Adaptive Disclosure (AD)', 'Standardized Treatment Name_Amitriptyline', 'Standardized Treatment Name_Animal Assisted', 'Standardized Treatment Name_Aripiprazole augmentation', 'Standardized Treatment Name_Art therapy + Cognitive Processing Therapy (CPT)', 'Standardized Treatment Name_Assessment', 'Standardized Treatment Name_Attention bias modification (ABM)', 'Standardized Treatment Name_Attention control', 'Standardized Treatment Name_Behavioral activation (BA)', 'Standardized Treatment Name_Biofeedback', 'Standardized Treatment Name_Biofeedback-assisted relaxation', 'Standardized Treatment Name_Bright light exposure', 'Standardized Treatment Name_Brofaromine', 'Standardized Treatment Name_Building Spiritual Strength', 'Standardized Treatment Name_Bupropion', 'Standardized Treatment Name_Citalopram + baclofen', 'Standardized Treatment Name_Citalopram + placebo', 'Standardized Treatment Name_Cognitive Applications for Life Management', 'Standardized Treatment Name_Cognitive Behavioral Conjoint Therapy (CBCT)', 'Standardized Treatment Name_Cognitive Behavioral Social Rhythm Group Therapy', 'Standardized Treatment Name_Cognitive Behavioral Therapy for Insomnia (CBT-I)', 'Standardized Treatment Name_Cognitive Behavioral Therapy for Insomnia (CBT-I) + Imagery Rehearsal Training (IRT)', 'Standardized Treatment Name_Cognitive Behavioral Therapy for Insomnia (CBT-I) + Imagery Rehearsal Training (IRT) followed by Cognitive Processing Therapy (CPT)', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT)', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) + Placebo', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) + Transcranial magnetic stimulation (TMS)', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) + Zonisamide', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) + sham', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) + smoking cessation', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) adapted for traumatic brain injury (TBI)', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) followed by Cognitive Behavioral Therapy for Insomnia (CBT-I) + Imagery Rehearsal Training (IRT)', 'Standardized Treatment Name_Cognitive behavioral therapy (CBT) without a trauma focus', 'Standardized Treatment Name_Cognitive behavioral therapy for headache (CBTH)', 'Standardized Treatment Name_Collaborative care', 'Standardized Treatment Name_Compassion meditation', 'Standardized Treatment Name_Concurrent Treatment for PTSD and Substance Use Disorder Using Prolonged Exposure (COPE)', 'Standardized Treatment Name_Control', 'Standardized Treatment Name_Creating Change', 'Standardized Treatment Name_Delta-9-tetrahydrocannabinol (THC) + Cannabidiol (CBD)', 'Standardized Treatment Name_Desipramine + naltrexone', 'Standardized Treatment Name_Desipramine + placebo', 'Standardized Treatment Name_Divalproex', 'Standardized Treatment Name_Doxazosin', 'Standardized Treatment Name_Electronic sleep diary', 'Standardized Treatment Name_Emotional Freedom Technique (EFT)', 'Standardized Treatment Name_Eszopiclone', 'Standardized Treatment Name_Exercise', 'Standardized Tre ...
#
# First 5 rows of the loaded DataFrame:
#            arm_id Group      Study ID Diagnostic Measure   Clinical Setting  \
# 0  abdallah2022_a     A  abdallah2022               CAPS  Outpatient clinic
# 1  abdallah2022_a     A  abdallah2022               CAPS  Outpatient clinic
# 2  abdallah2022_a     A  abdallah2022               CAPS  Outpatient clinic
# 3  abdallah2022_a     A  abdallah2022               CAPS  Outpatient clinic
# 4  abdallah2022_a     A  abdallah2022               CAPS  Outpatient clinic
#
#   Military Status  Veteran Percent  Female Percent  Male Percent  baseline_z  \
# 0           Mixed            67.72           23.42         76.58   -0.548164
# 1           Mixed            67.72           23.42         76.58   -0.049524
# 2           Mixed            67.72           23.42         76.58   -0.548164
# 3           Mixed            67.72           23.42         76.58   -0.049524
# 4           Mixed            67.72           23.42         76.58   -0.548164
#
#    treatment_duration  baseline_severity  Percent Achieved Diagnostic Change  \
# 0                 4.0               38.5                                30.7
# 1                 4.0               47.5                                30.7
# 2                 4.0               38.5                                30.7
# 3                 4.0               47.5                                30.7
# 4                 4.0               38.5                                30.7
#
#    binary_outcome  Trauma Type_Combat-related  Trauma Type_MST  \
# 0             0.0                       False            False
# 1             0.0                       False            False
# 2             0.0                       False            False
# 3             0.0                       False            False
# 4             0.0                       False            False
#
#    Trauma Type_Mixed  Trauma Type_Other  Delivery Method_In Person  \
# 0              False              False                       True
# 1              False              False                       True
# 2              False              False                       True
# 3              False              False                       True
# 4              False              False                       True
#
#    Delivery Method_In person  Delivery Method_Mixed  Delivery Method_Phone  \
# 0                      False                  False                  False
# 1                      False                  False                  False
# 2                      False                  False                  False
# 3                      False                  False                  False
# 4                      False                  False                  False
#
#    Delivery Method_Technology Alone  Delivery Method_Technology Assisted  \
# 0                             False                                False
# 1                             False                                False
# 2                             False                                False
# 3                             False                                False
# 4                             False                                False
#
#    Delivery Method_Technology alone  Delivery Method_Technology assisted  \
# 0                             False                                False
# 1                             False                                False
# 2                             False                                False
# 3                             False                                False
# 4                             False                                False
#
#    Delivery Method_Video  Delivery Method_Written  \
# 0                  False                    False
# 1                  False                    False
# 2                  False                    False
# 3                  False                    False
# 4                  False                    False
#
#    Standardized Treatment Name_Accelerated Resolution Therapy (ART)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Acupuncture  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    Standardized Treatment Name_Adaptive Disclosure (AD)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Amitriptyline  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    Standardized Treatment Name_Animal Assisted  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
#
#    Standardized Treatment Name_Aripiprazole augmentation  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Art therapy + Cognitive Processing Therapy (CPT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Assessment  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    Standardized Treatment Name_Attention bias modification (ABM)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Attention control  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    Standardized Treatment Name_Behavioral activation (BA)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Biofeedback  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    Standardized Treatment Name_Biofeedback-assisted relaxation  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Bright light exposure  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Brofaromine  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    Standardized Treatment Name_Building Spiritual Strength  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Bupropion  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#    Standardized Treatment Name_Citalopram + baclofen  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Citalopram + placebo  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
#
#    Standardized Treatment Name_Cognitive Applications for Life Management  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Behavioral Conjoint Therapy (CBCT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Behavioral Social Rhythm Group Therapy  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Behavioral Therapy for Insomnia (CBT-I)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Behavioral Therapy for Insomnia (CBT-I) + Imagery Rehearsal Training (IRT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Behavioral Therapy for Insomnia (CBT-I) + Imagery Rehearsal Training (IRT) followed by Cognitive Processing Therapy (CPT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Processing Therapy (CPT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Processing Therapy (CPT) + Placebo  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Processing Therapy (CPT) + Transcranial magnetic stimulation (TMS)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Processing Therapy (CPT) + Zonisamide  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Processing Therapy (CPT) + sham  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Processing Therapy (CPT) + smoking cessation  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Processing Therapy (CPT) adapted for traumatic brain injury (TBI)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Processing Therapy (CPT) followed by Cognitive Behavioral Therapy for Insomnia (CBT-I) + Imagery Rehearsal Training (IRT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive behavioral therapy (CBT) without a trauma focus  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive behavioral therapy for headache (CBTH)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Collaborative care  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    Standardized Treatment Name_Compassion meditation  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Concurrent Treatment for PTSD and Substance Use Disorder Using Prolonged Exposure (COPE)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Control  \
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
#
#    Standardized Treatment Name_Creating Change  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
#
#    Standardized Treatment Name_Delta-9-tetrahydrocannabinol (THC) + Cannabidiol (CBD)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Desipramine + naltrexone  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Desipramine + placebo  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Divalproex  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    Standardized Treatment Name_Doxazosin  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#    Standardized Treatment Name_Electronic sleep diary  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Emotional Freedom Technique (EFT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Eszopiclone  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    Standardized Treatment Name_Exercise  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#    Standardized Treatment Name_Experiential Acceptance  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Exposure therapy  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    Standardized Treatment Name_Eye Movement Desensitization and Reprocessing (EMDR)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Fitness/career assessment and planning  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Fluoxetine  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    Standardized Treatment Name_Guanfacine  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    Standardized Treatment Name_Healing Touch  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    Standardized Treatment Name_High Cannabidiol (CBD) and low Delta-9-tetrahydrocannabinol (THC)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_High Delta-9-tetrahydrocannabinol (THC) and low Cannabidiol (CBD)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Holographic reprocessing  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Hydrocortisone prior to Prolonged Exposure (PE)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Hyperbaric oxygen therapy (HBOT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Imagery Rehearsal Training (IRT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Imagery Rehearsal Training (IRT) + Cognitive Behavioral Therapy for Insomnia (CBT-I)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Imaginal exposure (experimental paradigm)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Imaginal exposure (experimental paradigm) + Placebo  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Imaginal exposure (experimental paradigm) +Dexamethasone  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Imaginal exposure +D-cycloserine  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Imipramine  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    Standardized Treatment Name_Impact of Killing  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    Standardized Treatment Name_Implosive Therapy  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    Standardized Treatment Name_Integrated Cognitive Behavioral Therapy (ICBT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Integrated Motivational Enhancement Therapy (MET) + Prolonged Exposure (PE)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Interdisciplinary treatment as usual  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Internet-based facilitated self-help  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Internet-based self-help  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Interpersonal Psychotherapy (IPT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Ketamine  \
# 0                                  True
# 1                                  True
# 2                                  True
# 3                                  True
# 4                                  True
#
#    Standardized Treatment Name_Ketorolac  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#    Standardized Treatment Name_Lamotrigine  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    Standardized Treatment Name_Lanicemine  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    Standardized Treatment Name_Loving kindness meditation  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Low Delta-9-tetrahydrocannabinol (THC) + low Cannabidiol (CBD)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_MDMA-assisted psychotherapy  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Mantram Repetition  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    Standardized Treatment Name_Memory specificity training  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Mifepristone  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    Standardized Treatment Name_Mindfulness  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    Standardized Treatment Name_Mindfulness meditation + slow breathing  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Mindfulness-based stress reduction (MBSR)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Minimal attention  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    Standardized Treatment Name_Mirtazapine  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    Standardized Treatment Name_Multi-modal Memory Restructuring (3MR)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Multi-modular motion-assisted memory desensitization and reconsolidation (3MDR)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Multi-modular motion-assisted memory desensitization and reconsolidation (3MDR) + eye movement  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Nefazodone  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    Standardized Treatment Name_Neurofeedback  \
# 0                                      False
# 1                                      False
# ...
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Riluzole  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#    Standardized Treatment Name_Risperidone  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    Standardized Treatment Name_Rivastigmine augmentation  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Seeking Safety  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
#    Standardized Treatment Name_Sertraline  Standardized Treatment Name_Sham  \
# 0                                   False                             False
# 1                                   False                             False
# 2                                   False                             False
# 3                                   False                             False
# 4                                   False                             False
#
#    Standardized Treatment Name_Sitting quietly  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
#
#    Standardized Treatment Name_Skills Training in Affect and Interpersonal Regulation (STAIR)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Sleep and nightmare management  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Smoking cessation  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    Standardized Treatment Name_Smoking cessation integrated into PTSD TAU  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Stellate ganglion block (SGB)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Structured Approach Therapy  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Supportive counseling  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Supportive counseling + naltrexone  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Supportive counseling + placebo  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Supportive psychotherapy + Cognitive Processing Therapy (CPT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_TNX-102 SL  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    Standardized Treatment Name_Text message-based facilitated self-help  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Topiramate  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    Standardized Treatment Name_Topiramate augmentation  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Transcendental meditation  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Transcranial magnetic stimualtion (TMS)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Trauma Management Therapy with exposure therapy  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Trauma-focused Psychotherapy  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Trauma-focused cognitive behavioral therapy (TF-CBT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Treatment as usual  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    Standardized Treatment Name_Treatment as usual (TAU)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Vilazodone  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    Standardized Treatment Name_Virtual reality exposure (VRET) + Transcranial direct current stimulation (tDCS)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Virtual reality exposure (VRET) + sham  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Virtual reality exposure therapy (VRET)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Virtual reality exposure therapy (VRET) + D-cycloserine  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Virtual reality exposure therapy (VRET) + alprazolam  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Virtual reality exposure therapy (VRET) + placebo  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Waitlist  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#    Standardized Treatment Name_Working memory training  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Written Exposure Therapy (WET)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Yoga  \
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False
#
#    Standardized Treatment Name_Ziprasidone augmentation  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_mifepristone
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False

# %% [markdown]
# ### Display Current DataFrame Columns and Head

# %%
print("All columns in the DataFrame:")
print(df.columns.tolist())

print("\nFirst 5 rows of the DataFrame (showing one-hot encoded columns):")
display(df.head())
# Out:
# All columns in the DataFrame:
# ['arm_id', 'Group', 'Study ID', 'Diagnostic Measure', 'Clinical Setting', 'Military Status', 'Veteran Percent', 'Female Percent', 'Male Percent', 'baseline_z', 'treatment_duration', 'baseline_severity', 'Percent Achieved Diagnostic Change', 'binary_outcome', 'Trauma Type_Combat-related', 'Trauma Type_MST', 'Trauma Type_Mixed', 'Trauma Type_Other', 'Delivery Method_In Person', 'Delivery Method_In person', 'Delivery Method_Mixed', 'Delivery Method_Phone', 'Delivery Method_Technology Alone', 'Delivery Method_Technology Assisted', 'Delivery Method_Technology alone', 'Delivery Method_Technology assisted', 'Delivery Method_Video', 'Delivery Method_Written', 'Standardized Treatment Name_Accelerated Resolution Therapy (ART)', 'Standardized Treatment Name_Acupuncture', 'Standardized Treatment Name_Adaptive Disclosure (AD)', 'Standardized Treatment Name_Amitriptyline', 'Standardized Treatment Name_Animal Assisted', 'Standardized Treatment Name_Aripiprazole augmentation', 'Standardized Treatment Name_Art therapy + Cognitive Processing Therapy (CPT)', 'Standardized Treatment Name_Assessment', 'Standardized Treatment Name_Attention bias modification (ABM)', 'Standardized Treatment Name_Attention control', 'Standardized Treatment Name_Behavioral activation (BA)', 'Standardized Treatment Name_Biofeedback', 'Standardized Treatment Name_Biofeedback-assisted relaxation', 'Standardized Treatment Name_Bright light exposure', 'Standardized Treatment Name_Brofaromine', 'Standardized Treatment Name_Building Spiritual Strength', 'Standardized Treatment Name_Bupropion', 'Standardized Treatment Name_Citalopram + baclofen', 'Standardized Treatment Name_Citalopram + placebo', 'Standardized Treatment Name_Cognitive Applications for Life Management', 'Standardized Treatment Name_Cognitive Behavioral Conjoint Therapy (CBCT)', 'Standardized Treatment Name_Cognitive Behavioral Social Rhythm Group Therapy', 'Standardized Treatment Name_Cognitive Behavioral Therapy for Insomnia (CBT-I)', 'Standardized Treatment Name_Cognitive Behavioral Therapy for Insomnia (CBT-I) + Imagery Rehearsal Training (IRT)', 'Standardized Treatment Name_Cognitive Behavioral Therapy for Insomnia (CBT-I) + Imagery Rehearsal Training (IRT) followed by Cognitive Processing Therapy (CPT)', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT)', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) + Placebo', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) + Transcranial magnetic stimulation (TMS)', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) + Zonisamide', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) + sham', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) + smoking cessation', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) adapted for traumatic brain injury (TBI)', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) followed by Cognitive Behavioral Therapy for Insomnia (CBT-I) + Imagery Rehearsal Training (IRT)', 'Standardized Treatment Name_Cognitive behavioral therapy (CBT) without a trauma focus', 'Standardized Treatment Name_Cognitive behavioral therapy for headache (CBTH)', 'Standardized Treatment Name_Collaborative care', 'Standardized Treatment Name_Compassion meditation', 'Standardized Treatment Name_Concurrent Treatment for PTSD and Substance Use Disorder Using Prolonged Exposure (COPE)', 'Standardized Treatment Name_Control', 'Standardized Treatment Name_Creating Change', 'Standardized Treatment Name_Delta-9-tetrahydrocannabinol (THC) + Cannabidiol (CBD)', 'Standardized Treatment Name_Desipramine + naltrexone', 'Standardized Treatment Name_Desipramine + placebo', 'Standardized Treatment Name_Divalproex', 'Standardized Treatment Name_Doxazosin', 'Standardized Treatment Name_Electronic sleep diary', 'Standardized Treatment Name_Emotional Freedom Technique (EFT)', 'Standardized Treatment Name_Eszopiclone', 'Standardized Treatment Name_Exercise', 'Standardized Tre ...
#
# First 5 rows of the DataFrame (showing one-hot encoded columns):
#            arm_id Group      Study ID Diagnostic Measure   Clinical Setting  \
# 0  abdallah2022_a     A  abdallah2022               CAPS  Outpatient clinic
# 1  abdallah2022_a     A  abdallah2022               CAPS  Outpatient clinic
# 2  abdallah2022_a     A  abdallah2022               CAPS  Outpatient clinic
# 3  abdallah2022_a     A  abdallah2022               CAPS  Outpatient clinic
# 4  abdallah2022_a     A  abdallah2022               CAPS  Outpatient clinic
#
#   Military Status  Veteran Percent  Female Percent  Male Percent  baseline_z  \
# 0           Mixed            67.72           23.42         76.58   -0.548164
# 1           Mixed            67.72           23.42         76.58   -0.049524
# 2           Mixed            67.72           23.42         76.58   -0.548164
# 3           Mixed            67.72           23.42         76.58   -0.049524
# 4           Mixed            67.72           23.42         76.58   -0.548164
#
#    treatment_duration  baseline_severity  Percent Achieved Diagnostic Change  \
# 0                 4.0               38.5                                30.7
# 1                 4.0               47.5                                30.7
# 2                 4.0               38.5                                30.7
# 3                 4.0               47.5                                30.7
# 4                 4.0               38.5                                30.7
#
#    binary_outcome  Trauma Type_Combat-related  Trauma Type_MST  \
# 0             0.0                       False            False
# 1             0.0                       False            False
# 2             0.0                       False            False
# 3             0.0                       False            False
# 4             0.0                       False            False
#
#    Trauma Type_Mixed  Trauma Type_Other  Delivery Method_In Person  \
# 0              False              False                       True
# 1              False              False                       True
# 2              False              False                       True
# 3              False              False                       True
# 4              False              False                       True
#
#    Delivery Method_In person  Delivery Method_Mixed  Delivery Method_Phone  \
# 0                      False                  False                  False
# 1                      False                  False                  False
# 2                      False                  False                  False
# 3                      False                  False                  False
# 4                      False                  False                  False
#
#    Delivery Method_Technology Alone  Delivery Method_Technology Assisted  \
# 0                             False                                False
# 1                             False                                False
# 2                             False                                False
# 3                             False                                False
# 4                             False                                False
#
#    Delivery Method_Technology alone  Delivery Method_Technology assisted  \
# 0                             False                                False
# 1                             False                                False
# 2                             False                                False
# 3                             False                                False
# 4                             False                                False
#
#    Delivery Method_Video  Delivery Method_Written  \
# 0                  False                    False
# 1                  False                    False
# 2                  False                    False
# 3                  False                    False
# 4                  False                    False
#
#    Standardized Treatment Name_Accelerated Resolution Therapy (ART)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Acupuncture  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    Standardized Treatment Name_Adaptive Disclosure (AD)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Amitriptyline  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    Standardized Treatment Name_Animal Assisted  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
#
#    Standardized Treatment Name_Aripiprazole augmentation  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Art therapy + Cognitive Processing Therapy (CPT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Assessment  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    Standardized Treatment Name_Attention bias modification (ABM)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Attention control  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    Standardized Treatment Name_Behavioral activation (BA)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Biofeedback  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    Standardized Treatment Name_Biofeedback-assisted relaxation  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Bright light exposure  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Brofaromine  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    Standardized Treatment Name_Building Spiritual Strength  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Bupropion  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#    Standardized Treatment Name_Citalopram + baclofen  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Citalopram + placebo  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
#
#    Standardized Treatment Name_Cognitive Applications for Life Management  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Behavioral Conjoint Therapy (CBCT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Behavioral Social Rhythm Group Therapy  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Behavioral Therapy for Insomnia (CBT-I)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Behavioral Therapy for Insomnia (CBT-I) + Imagery Rehearsal Training (IRT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Behavioral Therapy for Insomnia (CBT-I) + Imagery Rehearsal Training (IRT) followed by Cognitive Processing Therapy (CPT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Processing Therapy (CPT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Processing Therapy (CPT) + Placebo  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Processing Therapy (CPT) + Transcranial magnetic stimulation (TMS)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Processing Therapy (CPT) + Zonisamide  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Processing Therapy (CPT) + sham  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Processing Therapy (CPT) + smoking cessation  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Processing Therapy (CPT) adapted for traumatic brain injury (TBI)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive Processing Therapy (CPT) followed by Cognitive Behavioral Therapy for Insomnia (CBT-I) + Imagery Rehearsal Training (IRT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive behavioral therapy (CBT) without a trauma focus  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Cognitive behavioral therapy for headache (CBTH)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Collaborative care  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    Standardized Treatment Name_Compassion meditation  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Concurrent Treatment for PTSD and Substance Use Disorder Using Prolonged Exposure (COPE)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Control  \
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
#
#    Standardized Treatment Name_Creating Change  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
#
#    Standardized Treatment Name_Delta-9-tetrahydrocannabinol (THC) + Cannabidiol (CBD)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Desipramine + naltrexone  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Desipramine + placebo  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Divalproex  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    Standardized Treatment Name_Doxazosin  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#    Standardized Treatment Name_Electronic sleep diary  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Emotional Freedom Technique (EFT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Eszopiclone  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    Standardized Treatment Name_Exercise  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#    Standardized Treatment Name_Experiential Acceptance  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Exposure therapy  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    Standardized Treatment Name_Eye Movement Desensitization and Reprocessing (EMDR)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Fitness/career assessment and planning  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Fluoxetine  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    Standardized Treatment Name_Guanfacine  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    Standardized Treatment Name_Healing Touch  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    Standardized Treatment Name_High Cannabidiol (CBD) and low Delta-9-tetrahydrocannabinol (THC)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_High Delta-9-tetrahydrocannabinol (THC) and low Cannabidiol (CBD)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Holographic reprocessing  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Hydrocortisone prior to Prolonged Exposure (PE)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Hyperbaric oxygen therapy (HBOT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Imagery Rehearsal Training (IRT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Imagery Rehearsal Training (IRT) + Cognitive Behavioral Therapy for Insomnia (CBT-I)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Imaginal exposure (experimental paradigm)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Imaginal exposure (experimental paradigm) + Placebo  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Imaginal exposure (experimental paradigm) +Dexamethasone  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Imaginal exposure +D-cycloserine  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Imipramine  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    Standardized Treatment Name_Impact of Killing  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    Standardized Treatment Name_Implosive Therapy  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    Standardized Treatment Name_Integrated Cognitive Behavioral Therapy (ICBT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Integrated Motivational Enhancement Therapy (MET) + Prolonged Exposure (PE)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Interdisciplinary treatment as usual  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Internet-based facilitated self-help  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Internet-based self-help  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Interpersonal Psychotherapy (IPT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Ketamine  \
# 0                                  True
# 1                                  True
# 2                                  True
# 3                                  True
# 4                                  True
#
#    Standardized Treatment Name_Ketorolac  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#    Standardized Treatment Name_Lamotrigine  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    Standardized Treatment Name_Lanicemine  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    Standardized Treatment Name_Loving kindness meditation  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Low Delta-9-tetrahydrocannabinol (THC) + low Cannabidiol (CBD)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_MDMA-assisted psychotherapy  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Mantram Repetition  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    Standardized Treatment Name_Memory specificity training  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Mifepristone  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    Standardized Treatment Name_Mindfulness  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    Standardized Treatment Name_Mindfulness meditation + slow breathing  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Mindfulness-based stress reduction (MBSR)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Minimal attention  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    Standardized Treatment Name_Mirtazapine  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    Standardized Treatment Name_Multi-modal Memory Restructuring (3MR)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Multi-modular motion-assisted memory desensitization and reconsolidation (3MDR)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Multi-modular motion-assisted memory desensitization and reconsolidation (3MDR) + eye movement  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Nefazodone  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    Standardized Treatment Name_Neurofeedback  \
# 0                                      False
# 1                                      False
# ...
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Riluzole  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#    Standardized Treatment Name_Risperidone  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    Standardized Treatment Name_Rivastigmine augmentation  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Seeking Safety  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
#    Standardized Treatment Name_Sertraline  Standardized Treatment Name_Sham  \
# 0                                   False                             False
# 1                                   False                             False
# 2                                   False                             False
# 3                                   False                             False
# 4                                   False                             False
#
#    Standardized Treatment Name_Sitting quietly  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
#
#    Standardized Treatment Name_Skills Training in Affect and Interpersonal Regulation (STAIR)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Sleep and nightmare management  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Smoking cessation  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    Standardized Treatment Name_Smoking cessation integrated into PTSD TAU  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Stellate ganglion block (SGB)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Structured Approach Therapy  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Supportive counseling  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Supportive counseling + naltrexone  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Supportive counseling + placebo  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Supportive psychotherapy + Cognitive Processing Therapy (CPT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_TNX-102 SL  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    Standardized Treatment Name_Text message-based facilitated self-help  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Topiramate  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    Standardized Treatment Name_Topiramate augmentation  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Transcendental meditation  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Transcranial magnetic stimualtion (TMS)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Trauma Management Therapy with exposure therapy  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Trauma-focused Psychotherapy  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Trauma-focused cognitive behavioral therapy (TF-CBT)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Treatment as usual  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    Standardized Treatment Name_Treatment as usual (TAU)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Vilazodone  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    Standardized Treatment Name_Virtual reality exposure (VRET) + Transcranial direct current stimulation (tDCS)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Virtual reality exposure (VRET) + sham  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Virtual reality exposure therapy (VRET)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Virtual reality exposure therapy (VRET) + D-cycloserine  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Virtual reality exposure therapy (VRET) + alprazolam  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Virtual reality exposure therapy (VRET) + placebo  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Waitlist  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#    Standardized Treatment Name_Working memory training  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Written Exposure Therapy (WET)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_Yoga  \
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False
#
#    Standardized Treatment Name_Ziprasidone augmentation  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Standardized Treatment Name_mifepristone
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False

# %% [markdown]
# ## 4.2 Final Dataset Overview

# %%
# ==========================
# FINAL DATASET OVERVIEW
# ==========================

n_observations = df.shape[0]
n_variables = df.shape[1]

print("Number of observations:", n_observations)
print("Number of variables:", n_variables)
# Out:
# Number of observations: 99491
# Number of variables: 203

# %% [markdown]
# ### Table 2: Final Dataset Overview

# %%
# ==========================
# TABLE 2
# FINAL DATASET OVERVIEW
# ==========================

table_2 = pd.DataFrame({
    'Characteristic': [
        'Number of observations',
        'Number of predictors',
        'Outcome variable',
        'Success threshold',
        'Missing data strategy'
    ],
    'Value': [
        df.shape[0],
        df.shape[1]-1,  # minus outcome variable
        'Binary Outcome',
        '≥50% diagnostic change',
        'Median imputation'
    ]
})

display(table_2)
# Out:
#            Characteristic                   Value
# 0  Number of observations                   99491
# 1    Number of predictors                     202
# 2        Outcome variable          Binary Outcome
# 3       Success threshold  ≥50% diagnostic change
# 4   Missing data strategy       Median imputation

# %% [markdown]
# ### Table 2 Export

# %%
table_2.to_excel(
    "Table_2_Final_Dataset_Overview.xlsx",
    index=False
)

print("Table 2 exported successfully to 'Table_2_Final_Dataset_Overview.xlsx'.")
# Out:
# Table 2 exported successfully to 'Table_2_Final_Dataset_Overview.xlsx'.

# %% [markdown]
# ### Missing Data Summary

# %%
# ==========================
# MISSING DATA CHECK
# ==========================

missing_summary = df.isnull().sum()

print("Total Missing Values:")
print(missing_summary.sum())

print("\nVariables with Missing Values:")
print(missing_summary[missing_summary > 0])
# Out:
# Total Missing Values:
# 0
#
# Variables with Missing Values:
# Series([], dtype: int64)

# %% [markdown]
# ### Dataset Suitability Statistics

# %% [markdown]
# ### Check Column Names

# %%
print("Confirming exact column names in the DataFrame:")
print(df.columns.tolist())
# Out:
# Confirming exact column names in the DataFrame:
# ['arm_id', 'Group', 'Study ID', 'Diagnostic Measure', 'Clinical Setting', 'Military Status', 'Veteran Percent', 'Female Percent', 'Male Percent', 'baseline_z', 'treatment_duration', 'baseline_severity', 'Percent Achieved Diagnostic Change', 'binary_outcome', 'Trauma Type_Combat-related', 'Trauma Type_MST', 'Trauma Type_Mixed', 'Trauma Type_Other', 'Delivery Method_In Person', 'Delivery Method_In person', 'Delivery Method_Mixed', 'Delivery Method_Phone', 'Delivery Method_Technology Alone', 'Delivery Method_Technology Assisted', 'Delivery Method_Technology alone', 'Delivery Method_Technology assisted', 'Delivery Method_Video', 'Delivery Method_Written', 'Standardized Treatment Name_Accelerated Resolution Therapy (ART)', 'Standardized Treatment Name_Acupuncture', 'Standardized Treatment Name_Adaptive Disclosure (AD)', 'Standardized Treatment Name_Amitriptyline', 'Standardized Treatment Name_Animal Assisted', 'Standardized Treatment Name_Aripiprazole augmentation', 'Standardized Treatment Name_Art therapy + Cognitive Processing Therapy (CPT)', 'Standardized Treatment Name_Assessment', 'Standardized Treatment Name_Attention bias modification (ABM)', 'Standardized Treatment Name_Attention control', 'Standardized Treatment Name_Behavioral activation (BA)', 'Standardized Treatment Name_Biofeedback', 'Standardized Treatment Name_Biofeedback-assisted relaxation', 'Standardized Treatment Name_Bright light exposure', 'Standardized Treatment Name_Brofaromine', 'Standardized Treatment Name_Building Spiritual Strength', 'Standardized Treatment Name_Bupropion', 'Standardized Treatment Name_Citalopram + baclofen', 'Standardized Treatment Name_Citalopram + placebo', 'Standardized Treatment Name_Cognitive Applications for Life Management', 'Standardized Treatment Name_Cognitive Behavioral Conjoint Therapy (CBCT)', 'Standardized Treatment Name_Cognitive Behavioral Social Rhythm Group Therapy', 'Standardized Treatment Name_Cognitive Behavioral Therapy for Insomnia (CBT-I)', 'Standardized Treatment Name_Cognitive Behavioral Therapy for Insomnia (CBT-I) + Imagery Rehearsal Training (IRT)', 'Standardized Treatment Name_Cognitive Behavioral Therapy for Insomnia (CBT-I) + Imagery Rehearsal Training (IRT) followed by Cognitive Processing Therapy (CPT)', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT)', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) + Placebo', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) + Transcranial magnetic stimulation (TMS)', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) + Zonisamide', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) + sham', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) + smoking cessation', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) adapted for traumatic brain injury (TBI)', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) followed by Cognitive Behavioral Therapy for Insomnia (CBT-I) + Imagery Rehearsal Training (IRT)', 'Standardized Treatment Name_Cognitive behavioral therapy (CBT) without a trauma focus', 'Standardized Treatment Name_Cognitive behavioral therapy for headache (CBTH)', 'Standardized Treatment Name_Collaborative care', 'Standardized Treatment Name_Compassion meditation', 'Standardized Treatment Name_Concurrent Treatment for PTSD and Substance Use Disorder Using Prolonged Exposure (COPE)', 'Standardized Treatment Name_Control', 'Standardized Treatment Name_Creating Change', 'Standardized Treatment Name_Delta-9-tetrahydrocannabinol (THC) + Cannabidiol (CBD)', 'Standardized Treatment Name_Desipramine + naltrexone', 'Standardized Treatment Name_Desipramine + placebo', 'Standardized Treatment Name_Divalproex', 'Standardized Treatment Name_Doxazosin', 'Standardized Treatment Name_Electronic sleep diary', 'Standardized Treatment Name_Emotional Freedom Technique (EFT)', 'Standardized Treatment Name_Eszopiclone', 'Standardized Treatment Name_Exercise', 'Standardized Tre ...

# %% [markdown]
# ### Create the Continuous Variables List

# %%
# Define the list of continuous variables based on your dataset and previous requests.
# Added 'Male Percent' and 'Percent Achieved Diagnostic Change' as discussed.
continuous_vars = [
    'Veteran Percent',
    'Female Percent',
    'Male Percent',
    'baseline_severity',
    'baseline_z',
    'treatment_duration',
    'Percent Achieved Diagnostic Change'
]

# Filter out any variables that might not exist in the current df, for robustness
continuous_vars = [col for col in continuous_vars if col in df.columns]

print(f"\nContinuous variables selected: {continuous_vars}")
# Out:
# Continuous variables selected: ['Veteran Percent', 'Female Percent', 'Male Percent', 'baseline_severity', 'baseline_z', 'treatment_duration', 'Percent Achieved Diagnostic Change']

# %% [markdown]
# ### Generate Descriptive Statistics

# %%
# =====================================
# DESCRIPTIVE STATISTICS
# =====================================

desc_stats = df[continuous_vars].describe().T
display(desc_stats)
# Out:
#                                       count       mean        std       min  \
# Veteran Percent                     99491.0  96.964144  14.629679  2.500000
# Female Percent                      99491.0  22.937389  30.122783  0.000000
# Male Percent                        99491.0  77.043638  30.147563  0.000000
# baseline_severity                   99491.0  61.424528  19.627651  2.030000
# baseline_z                          99491.0   0.721957   1.087459 -2.568764
# treatment_duration                  99491.0   9.849588   3.350371  0.140000
# Percent Achieved Diagnostic Change  99491.0  33.692853  11.654696  2.100000
#
#                                            25%         50%         75%  \
# Veteran Percent                     100.000000  100.000000  100.000000
# Female Percent                        0.000000   16.200000   22.600000
# Male Percent                         77.400000   83.800000  100.000000
# baseline_severity                    54.670000   54.670000   76.050000
# baseline_z                            0.347726    0.347726    1.532274
# treatment_duration                    8.000000    8.000000   12.000000
# Percent Achieved Diagnostic Change   30.700000   30.700000   30.700000
#
#                                            max
# Veteran Percent                     100.000000
# Female Percent                      100.000000
# Male Percent                        100.000000
# baseline_severity                   129.300000
# baseline_z                            4.482561
# treatment_duration                   78.000000
# Percent Achieved Diagnostic Change   96.300000

# %% [markdown]
# ### Create Dissertation Table 3 (Descriptive Statistics)

# %%
# =====================================
# TABLE 3
# DESCRIPTIVE STATISTICS
# =====================================

table_3 = pd.DataFrame({
    'Variable': desc_stats.index,
    'Mean': desc_stats['mean'].round(2),
    'SD': desc_stats['std'].round(2),
    'Min': desc_stats['min'].round(2),
    'Max': desc_stats['max'].round(2)
})

display(table_3)
# Out:
#                                                               Variable   Mean  \
# Veteran Percent                                        Veteran Percent  96.96
# Female Percent                                          Female Percent  22.94
# Male Percent                                              Male Percent  77.04
# baseline_severity                                    baseline_severity  61.42
# baseline_z                                                  baseline_z   0.72
# treatment_duration                                  treatment_duration   9.85
# Percent Achieved Diagnostic Change  Percent Achieved Diagnostic Change  33.69
#
#                                        SD   Min     Max
# Veteran Percent                     14.63  2.50  100.00
# Female Percent                      30.12  0.00  100.00
# Male Percent                        30.15  0.00  100.00
# baseline_severity                   19.63  2.03  129.30
# baseline_z                           1.09 -2.57    4.48
# treatment_duration                   3.35  0.14   78.00
# Percent Achieved Diagnostic Change  11.65  2.10   96.30

# %% [markdown]
# Export Table for Word

# %%
table_3.to_excel(
    "Table_3_Descriptive_Statistics.xlsx",
    index=False
)

print("\nTable 3 exported successfully to 'Table_3_Descriptive_Statistics.xlsx'.")
# Out:
# Table 3 exported successfully to 'Table_3_Descriptive_Statistics.xlsx'.

# %% [markdown]
# ### Additional Analysis: Generate Histograms for Continuous Variables

# %% [markdown]
# ### Overall Dataset Suitability Check

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Ensure the output directory exists
output_image_dir = os.path.join(data_path, 'histograms')
os.makedirs(output_image_dir, exist_ok=True)

for col in continuous_vars:
    plt.figure(figsize=(8,5))
    sns.histplot(df[col].dropna(), bins=30, kde=True, edgecolor='black') # Using seaborn for better aesthetics and KDE
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(axis='y', alpha=0.75)

    # Save the figure
    image_filename = f"distribution_of_{col.replace(' ', '_').replace('%', 'percent')}.png"
    image_filepath = os.path.join(output_image_dir, image_filename)
    plt.savefig(image_filepath, bbox_inches='tight')
    print(f"Histogram for '{col}' saved to: {image_filepath}")

    plt.show()
# Out:
# Histogram for 'Veteran Percent' saved to: /content/drive/MyDrive/Colab Notebooks/Data set/histograms/distribution_of_Veteran_Percent.png
# Histogram for 'Female Percent' saved to: /content/drive/MyDrive/Colab Notebooks/Data set/histograms/distribution_of_Female_Percent.png
# Histogram for 'Male Percent' saved to: /content/drive/MyDrive/Colab Notebooks/Data set/histograms/distribution_of_Male_Percent.png
# Histogram for 'baseline_severity' saved to: /content/drive/MyDrive/Colab Notebooks/Data set/histograms/distribution_of_baseline_severity.png
# Histogram for 'baseline_z' saved to: /content/drive/MyDrive/Colab Notebooks/Data set/histograms/distribution_of_baseline_z.png
# Histogram for 'treatment_duration' saved to: /content/drive/MyDrive/Colab Notebooks/Data set/histograms/distribution_of_treatment_duration.png
# Histogram for 'Percent Achieved Diagnostic Change' saved to: /content/drive/MyDrive/Colab Notebooks/Data set/histograms/distribution_of_Percent_Achieved_Diagnostic_Change.png

# %%
# ==========================
# DATASET SUITABILITY
# ==========================

print("Observations:", df.shape[0])
print("Variables:", df.shape[1])

print("\nOutcome Distribution:")
print(df['binary_outcome'].value_counts())

print("\nOutcome Percentage:")
print(
    round(
        df['binary_outcome'].value_counts(normalize=True)*100,
        2
    )
)
# Out:
# Observations: 99491
# Variables: 203
#
# Outcome Distribution:
# binary_outcome
# 0.0    87642
# 1.0    11849
# Name: count, dtype: int64
#
# Outcome Percentage:
# binary_outcome
# 0.0    88.09
# 1.0    11.91
# Name: proportion, dtype: float64

# %% [markdown]
# ### Outcome Frequency Table

# %% [markdown]
# ## 4.3 Distribution of Treatment Success
#
# This section assesses the distribution of the `binary_outcome` variable, which is crucial for understanding class imbalance in the dataset.

# %% [markdown]
# ### Outcome Frequency Table

# %%
outcome_counts = (
    df['binary_outcome']
    .value_counts()
    .sort_index()
)

outcome_percentages = (
    df['binary_outcome']
    .value_counts(normalize=True)
    .sort_index() * 100
)

table_4 = pd.DataFrame({
    'Outcome': ['Failure (0)', 'Success (1)'],
    'Frequency': outcome_counts.values,
    'Percentage': outcome_percentages.round(2).values
})

display(table_4)
# Out:
#        Outcome  Frequency  Percentage
# 0  Failure (0)      87642       88.09
# 1  Success (1)      11849       11.91

# %% [markdown]
# ### Table 4 Export

# %%
table_4.to_excel(
    "Table_4_Outcome_Distribution.xlsx",
    index=False
)
print("Table 4 exported successfully to 'Table_4_Outcome_Distribution.xlsx'.")
# Out:
# Table 4 exported successfully to 'Table_4_Outcome_Distribution.xlsx'.

# %% [markdown]
# ### Generate Figure 13

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,5))

df['binary_outcome'].value_counts().sort_index().plot(
    kind='bar',
    color=['skyblue', 'lightcoral'] # Added colors for better visualization
)

plt.title('Distribution of Treatment Outcomes')
plt.xlabel('Outcome')
plt.ylabel('Frequency')

plt.xticks(
    [0,1],
    ['Failure (0)', 'Success (1)'],
    rotation=0
)

plt.tight_layout()

plt.savefig(
    'Figure_13_Outcome_Distribution.png',
    dpi=300,
    bbox_inches='tight'
)

print("Figure 13 saved to 'Figure_13_Outcome_Distribution.png'.")
plt.show()
# Out:
# Figure 13 saved to 'Figure_13_Outcome_Distribution.png'.

# %% [markdown]
# ## 4.4 Logistic Regression Model Development

# %%
for col in df.columns:
    print(col)
# Out:
# arm_id
# Group
# Study ID
# Diagnostic Measure
# Clinical Setting
# Military Status
# Veteran Percent
# Female Percent
# Male Percent
# baseline_z
# treatment_duration
# baseline_severity
# Percent Achieved Diagnostic Change
# binary_outcome
# Trauma Type_Combat-related
# Trauma Type_MST
# Trauma Type_Mixed
# Trauma Type_Other
# Delivery Method_In Person
# Delivery Method_In person
# Delivery Method_Mixed
# Delivery Method_Phone
# Delivery Method_Technology Alone
# Delivery Method_Technology Assisted
# Delivery Method_Technology alone
# Delivery Method_Technology assisted
# Delivery Method_Video
# Delivery Method_Written
# Standardized Treatment Name_Accelerated Resolution Therapy (ART)
# Standardized Treatment Name_Acupuncture
# Standardized Treatment Name_Adaptive Disclosure (AD)
# Standardized Treatment Name_Amitriptyline
# Standardized Treatment Name_Animal Assisted
# Standardized Treatment Name_Aripiprazole augmentation
# Standardized Treatment Name_Art therapy + Cognitive Processing Therapy (CPT)
# Standardized Treatment Name_Assessment
# Standardized Treatment Name_Attention bias modification (ABM)
# Standardized Treatment Name_Attention control
# Standardized Treatment Name_Behavioral activation (BA)
# Standardized Treatment Name_Biofeedback
# Standardized Treatment Name_Biofeedback-assisted relaxation
# Standardized Treatment Name_Bright light exposure
# Standardized Treatment Name_Brofaromine
# Standardized Treatment Name_Building Spiritual Strength
# Standardized Treatment Name_Bupropion
# Standardized Treatment Name_Citalopram + baclofen
# Standardized Treatment Name_Citalopram + placebo
# Standardized Treatment Name_Cognitive Applications for Life Management
# Standardized Treatment Name_Cognitive Behavioral Conjoint Therapy (CBCT)
# Standardized Treatment Name_Cognitive Behavioral Social Rhythm Group Therapy
# Standardized Treatment Name_Cognitive Behavioral Therapy for Insomnia (CBT-I)
# Standardized Treatment Name_Cognitive Behavioral Therapy for Insomnia (CBT-I) + Imagery Rehearsal Training (IRT)
# Standardized Treatment Name_Cognitive Behavioral Therapy for Insomnia (CBT-I) + Imagery Rehearsal Training (IRT) followed by Cognitive Processing Therapy (CPT)
# Standardized Treatment Name_Cognitive Processing Therapy (CPT)
# Standardized Treatment Name_Cognitive Processing Therapy (CPT) + Placebo
# Standardized Treatment Name_Cognitive Processing Therapy (CPT) + Transcranial magnetic stimulation (TMS)
# Standardized Treatment Name_Cognitive Processing Therapy (CPT) + Zonisamide
# Standardized Treatment Name_Cognitive Processing Therapy (CPT) + sham
# Standardized Treatment Name_Cognitive Processing Therapy (CPT) + smoking cessation
# Standardized Treatment Name_Cognitive Processing Therapy (CPT) adapted for traumatic brain injury (TBI)
# Standardized Treatment Name_Cognitive Processing Therapy (CPT) followed by Cognitive Behavioral Therapy for Insomnia (CBT-I) + Imagery Rehearsal Training (IRT)
# Standardized Treatment Name_Cognitive behavioral therapy (CBT) without a trauma focus
# Standardized Treatment Name_Cognitive behavioral therapy for headache (CBTH)
# Standardized Treatment Name_Collaborative care
# Standardized Treatment Name_Compassion meditation
# Standardized Treatment Name_Concurrent Treatment for PTSD and Substance Use Disorder Using Prolonged Exposure (COPE)
# Standardized Treatment Name_Control
# Standardized Treatment Name_Creating Change
# Standardized Treatment Name_Delta-9-tetrahydrocannabinol (THC) + Cannabidiol (CBD)
# Standardized Treatment Name_Desipramine + naltrexone
# Standardized Treatment Name_Desipramine + placebo
# Standardized Treatment Name_Divalproex
# Standardized Treatment Name_Doxazosin
# Standardized Treatment Name_Electronic sleep diary
# Standardized Treatment Name_Emotional Freedom Technique (EFT)
# Standardized Treatment Name_Eszopiclone
# Standardized Treatment Name_Exercise
# Standardized Treatment Name_Experiential Acceptance
# Standardized Treatment Name_Exposure therapy
# Standardized Treatment Name_Eye Movement Desensitization and Reprocessing (EMDR)
# Standardized Treatment Name_Fitness/career assessment and planning
# Standardized Treatment Name_Fluoxetine
# Standardized Treatment Name_Guanfacine
# Standardized Treatment Name_Healing Touch
# Standardized Treatment Name_High Cannabidiol (CBD) and low Delta-9-tetrahydrocannabinol (THC)
# Standardized Treatment Name_High Delta-9-tetrahydrocannabinol (THC) and low Cannabidiol (CBD)
# Standardized Treatment Name_Holographic reprocessing
# Standardized Treatment Name_Hydrocortisone prior to Prolonged Exposure (PE)
# Standardized Treatment Name_Hyperbaric oxygen therapy (HBOT)
# Standardized Treatment Name_Imagery Rehearsal Training (IRT)
# Standardized Treatment Name_Imagery Rehearsal Training (IRT) + Cognitive Behavioral Therapy for Insomnia (CBT-I)
# Standardized Treatment Name_Imaginal exposure (experimental paradigm)
# Standardized Treatment Name_Imaginal exposure (experimental paradigm) + Placebo
# Standardized Treatment Name_Imaginal exposure (experimental paradigm) +Dexamethasone
# Standardized Treatment Name_Imaginal exposure +D-cycloserine
# Standardized Treatment Name_Imipramine
# Standardized Treatment Name_Impact of Killing
# Standardized Treatment Name_Implosive Therapy
# Standardized Treatment Name_Integrated Cognitive Behavioral Therapy (ICBT)
# Standardized Treatment Name_Integrated Motivational Enhancement Therapy (MET) + Prolonged Exposure (PE)
# Standardized Treatment Name_Interdisciplinary treatment as usual
# Standardized Treatment Name_Internet-based facilitated self-help
# Standardized Treatment Name_Internet-based self-help
# Standardized Treatment Name_Interpersonal Psychotherapy (IPT)
# Standardized Treatment Name_Ketamine
# Standardized Treatment Name_Ketorolac
# Standardized Treatment Name_Lamotrigine
# Standardized Treatment Name_Lanicemine
# Standardized Treatment Name_Loving kindness meditation
# Standardized Treatment Name_Low Delta-9-tetrahydrocannabinol (THC) + low Cannabidiol (CBD)
# Standardized Treatment Name_MDMA-assisted psychotherapy
# Standardized Treatment Name_Mantram Repetition
# Standardized Treatment Name_Memory specificity training
# Standardized Treatment Name_Mifepristone
# Standardized Treatment Name_Mindfulness
# Standardized Treatment Name_Mindfulness meditation + slow breathing
# Standardized Treatment Name_Mindfulness-based stress reduction (MBSR)
# Standardized Treatment Name_Minimal attention
# Standardized Treatment Name_Mirtazapine
# Standardized Treatment Name_Multi-modal Memory Restructuring (3MR)
# Standardized Treatment Name_Multi-modular motion-assisted memory desensitization and reconsolidation (3MDR)
# Standardized Treatment Name_Multi-modular motion-assisted memory desensitization and reconsolidation (3MDR) + eye movement
# Standardized Treatment Name_Nefazodone
# Standardized Treatment Name_Neurofeedback
# Standardized Treatment Name_Olanzapine
# Standardized Treatment Name_Olanzapine augmentation
# Standardized Treatment Name_PTSD Family Education
# Standardized Treatment Name_PTSD TAU with referral to smoking cessation clinic
# Standardized Treatment Name_Paroxetine
# Standardized Treatment Name_Paroxetine + naltrexone
# Standardized Treatment Name_Paroxetine + placebo
# Standardized Treatment Name_Person centered Therapy
# Standardized Treatment Name_Phased Motivational Enhancement Therapy (MET) + Prolonged Exposure (PE)
# Standardized Treatment Name_Phenelzine
# Standardized Treatment Name_Placebo
# Standardized Treatment Name_Placebo augmentation
# Standardized Treatment Name_Prazosin
# Standardized Treatment Name_Pregabalin
# Standardized Treatment Name_Present-Centered Therapy (PCT)
# Standardized Treatment Name_Primary Care Treatment Integrating Motivation and Exposure (PC-TIME)
# Standardized Treatment Name_Prolonged Exposure (PE)
# Standardized Treatment Name_Prolonged Exposure (PE) + D-cycloserine
# Standardized Treatment Name_Prolonged Exposure (PE) + hydrocortisone
# Standardized Treatment Name_Prolonged Exposure (PE) + ketamine
# Standardized Treatment Name_Prolonged Exposure (PE) + midazolam
# Standardized Treatment Name_Prolonged Exposure (PE) + naltrexone
# Standardized Treatment Name_Prolonged Exposure (PE) + oxytocin
# Standardized Treatment Name_Prolonged Exposure (PE) + placebo
# Standardized Treatment Name_Prolonged Exposure (PE) + quetiapine
# Standardized Treatment Name_Prolonged Exposure (PE) + yohimbine
# Standardized Treatment Name_Psychoeducation
# Standardized Treatment Name_Psychotherapy
# Standardized Treatment Name_Psychotherapy as usual
# Standardized Treatment Name_Quetiapine
# Standardized Treatment Name_Reconsolidation of Traumatic Memories (RTM)
# Standardized Treatment Name_Recreational therapy
# Standardized Treatment Name_Recreational therapy + inpatient therapy
# Standardized Treatment Name_Relapse Prevention
# Standardized Treatment Name_Relaxation
# Standardized Treatment Name_Relaxation with deep breathing and biofeedback
# Standardized Treatment Name_Relaxation with deep breathing exercise
# Standardized Treatment Name_Resilience-oriented treatment
# Standardized Treatment Name_Riluzole
# Standardized Treatment Name_Risperidone
# Standardized Treatment Name_Rivastigmine augmentation
# Standardized Treatment Name_Seeking Safety
# Standardized Treatment Name_Sertraline
# Standardized Treatment Name_Sham
# Standardized Treatment Name_Sitting quietly
# Standardized Treatment Name_Skills Training in Affect and Interpersonal Regulation (STAIR)
# Standardized Treatment Name_Sleep and nightmare management
# Standardized Treatment Name_Smoking cessation
# Standardized Treatment Name_Smoking cessation integrated into PTSD TAU
# Standardized Treatment Name_Stellate ganglion block (SGB)
# Standardized Treatment Name_Structured Approach Therapy
# Standardized Treatment Name_Supportive counseling
# Standardized Treatment Name_Supportive counseling + naltrexone
# Standardized Treatment Name_Supportive counseling + placebo
# Standardized Treatment Name_Supportive psychotherapy + Cognitive Processing Therapy (CPT)
# Standardized Treatment Name_TNX-102 SL
# Standardized Treatment Name_Text message-based facilitated self-help
# Standardized Treatment Name_Topiramate
# Standardized Treatment Name_Topiramate augmentation
# Standardized Treatment Name_Transcendental meditation
# Standardized Treatment Name_Transcranial magnetic stimualtion (TMS)
# Standardized Treatment Name_Trauma Management Therapy with exposure therapy
# Standardized Treatment Name_Trauma-focused Psychotherapy
# Standardized Treatment Name_Trauma-focused cognitive behavioral therapy (TF-CBT)
# Standardized Treatment Name_Treatment as usual
# Standardized Treatment Name_Treatment as usual (TAU)
# Standardized Treatment Name_Vilazodone
# Standardized Treatment Name_Virtual reality exposure (VRET) + Transcranial direct current stimulation (tDCS)
# Standardized Treatment Name_Virtual reality exposure (VRET) + sham
# Standardized Treatment Name_Virtual reality exposure therapy (VRET)
# Standardized Treatment Name_Virtual reality exposure therapy (VRET) + D-cycloserine
# Standardized Treatment Name_Virtual reality exposure therapy (VRET) + alprazolam
# Standardized Treatment Name_Virtual reality exposure therapy (VRET) + placebo
# Standardized Treatment Name_Waitlist
# Standardized Treatment Name_Working memory training
# Standardized Treatment Name_Written Exposure Therapy (WET)
# Standardized Treatment Name_Yoga
# Standardized Treatment Name_Ziprasidone augmentation
# Standardized Treatment Name_mifepristone

# %% [markdown]
# ### One-Hot Encode Remaining Categorical Features

# %%
df = pd.get_dummies(df, columns=['Diagnostic Measure', 'Clinical Setting', 'Military Status', 'Group'])

# %% [markdown]
# ### Verify Columns After One-Hot Encoding

# %%
print('Columns after one-hot encoding:')
print(df.columns.tolist())
print(f'New shape: {df.shape}')
# Out:
# Columns after one-hot encoding:
# ['arm_id', 'Study ID', 'Veteran Percent', 'Female Percent', 'Male Percent', 'baseline_z', 'treatment_duration', 'baseline_severity', 'Percent Achieved Diagnostic Change', 'binary_outcome', 'Trauma Type_Combat-related', 'Trauma Type_MST', 'Trauma Type_Mixed', 'Trauma Type_Other', 'Delivery Method_In Person', 'Delivery Method_In person', 'Delivery Method_Mixed', 'Delivery Method_Phone', 'Delivery Method_Technology Alone', 'Delivery Method_Technology Assisted', 'Delivery Method_Technology alone', 'Delivery Method_Technology assisted', 'Delivery Method_Video', 'Delivery Method_Written', 'Standardized Treatment Name_Accelerated Resolution Therapy (ART)', 'Standardized Treatment Name_Acupuncture', 'Standardized Treatment Name_Adaptive Disclosure (AD)', 'Standardized Treatment Name_Amitriptyline', 'Standardized Treatment Name_Animal Assisted', 'Standardized Treatment Name_Aripiprazole augmentation', 'Standardized Treatment Name_Art therapy + Cognitive Processing Therapy (CPT)', 'Standardized Treatment Name_Assessment', 'Standardized Treatment Name_Attention bias modification (ABM)', 'Standardized Treatment Name_Attention control', 'Standardized Treatment Name_Behavioral activation (BA)', 'Standardized Treatment Name_Biofeedback', 'Standardized Treatment Name_Biofeedback-assisted relaxation', 'Standardized Treatment Name_Bright light exposure', 'Standardized Treatment Name_Brofaromine', 'Standardized Treatment Name_Building Spiritual Strength', 'Standardized Treatment Name_Bupropion', 'Standardized Treatment Name_Citalopram + baclofen', 'Standardized Treatment Name_Citalopram + placebo', 'Standardized Treatment Name_Cognitive Applications for Life Management', 'Standardized Treatment Name_Cognitive Behavioral Conjoint Therapy (CBCT)', 'Standardized Treatment Name_Cognitive Behavioral Social Rhythm Group Therapy', 'Standardized Treatment Name_Cognitive Behavioral Therapy for Insomnia (CBT-I)', 'Standardized Treatment Name_Cognitive Behavioral Therapy for Insomnia (CBT-I) + Imagery Rehearsal Training (IRT)', 'Standardized Treatment Name_Cognitive Behavioral Therapy for Insomnia (CBT-I) + Imagery Rehearsal Training (IRT) followed by Cognitive Processing Therapy (CPT)', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT)', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) + Placebo', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) + Transcranial magnetic stimulation (TMS)', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) + Zonisamide', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) + sham', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) + smoking cessation', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) adapted for traumatic brain injury (TBI)', 'Standardized Treatment Name_Cognitive Processing Therapy (CPT) followed by Cognitive Behavioral Therapy for Insomnia (CBT-I) + Imagery Rehearsal Training (IRT)', 'Standardized Treatment Name_Cognitive behavioral therapy (CBT) without a trauma focus', 'Standardized Treatment Name_Cognitive behavioral therapy for headache (CBTH)', 'Standardized Treatment Name_Collaborative care', 'Standardized Treatment Name_Compassion meditation', 'Standardized Treatment Name_Concurrent Treatment for PTSD and Substance Use Disorder Using Prolonged Exposure (COPE)', 'Standardized Treatment Name_Control', 'Standardized Treatment Name_Creating Change', 'Standardized Treatment Name_Delta-9-tetrahydrocannabinol (THC) + Cannabidiol (CBD)', 'Standardized Treatment Name_Desipramine + naltrexone', 'Standardized Treatment Name_Desipramine + placebo', 'Standardized Treatment Name_Divalproex', 'Standardized Treatment Name_Doxazosin', 'Standardized Treatment Name_Electronic sleep diary', 'Standardized Treatment Name_Emotional Freedom Technique (EFT)', 'Standardized Treatment Name_Eszopiclone', 'Standardized Treatment Name_Exercise', 'Standardized Treatment Name_Experiential Acceptance', 'Standardized Treatment Name_Exp ...
# New shape: (99491, 244)

# %% [markdown]
# ### Define Features (X) and Target (y) for Logistic Regression

# %%
y = df['binary_outcome']

X = df.drop(columns=[
    'arm_id',
    'Study ID',
    'binary_outcome',
    'Percent Achieved Diagnostic Change',
    'Male Percent',
    'baseline_severity'
])

print("X shape:", X.shape)
print("y shape:", y.shape)
print("\nTarget variable (y) value counts:")
print(y.value_counts())
# Out:
# X shape: (99491, 238)
# y shape: (99491,)
#
# Target variable (y) value counts:
# binary_outcome
# 0.0    87642
# 1.0    11849
# Name: count, dtype: int64

# %% [markdown]
# ### Verify Data Types of Features

# %%
print(X.dtypes.value_counts())
# Out:
# bool       234
# float64      4
# Name: count, dtype: int64

# %% [markdown]
# ### Check for Missing Values in Features

# %%
print("Missing values:", X.isnull().sum().sum())
# Out:
# Missing values: 0

# %% [markdown]
# ### Verify Data Types and Missing Values (Redundant Check)

# %%
print(X.dtypes.value_counts())
print("Missing values:", X.isnull().sum().sum())
# Out:
# bool       234
# float64      4
# Name: count, dtype: int64
# Missing values: 0

# %% [markdown]
# ### Summarize Predictor Categories

# %%
predictor_summary = {
    "Veteran Percent": sum(col == "Veteran Percent" for col in X.columns),
    "Female Percent": sum(col == "Female Percent" for col in X.columns),
    "baseline_z": sum(col == "baseline_z" for col in X.columns),
    "treatment_duration": sum(col == "treatment_duration" for col in X.columns),

    "Trauma Type": sum(col.startswith("Trauma Type_") for col in X.columns),
    "Delivery Method": sum(col.startswith("Delivery Method_") for col in X.columns),
    "Treatment Name": sum(col.startswith("Standardized Treatment Name_") for col in X.columns),
    "Diagnostic Measure": sum(col.startswith("Diagnostic Measure_") for col in X.columns),
    "Clinical Setting": sum(col.startswith("Clinical Setting_") for col in X.columns),
    "Military Status": sum(col.startswith("Military Status_") for col in X.columns),
    "Group": sum(col.startswith("Group_") for col in X.columns)
}

for k, v in predictor_summary.items():
    print(f"{k}: {v}")
# Out:
# Veteran Percent: 1
# Female Percent: 1
# baseline_z: 1
# treatment_duration: 1
# Trauma Type: 4
# Delivery Method: 10
# Treatment Name: 175
# Diagnostic Measure: 25
# Clinical Setting: 14
# Military Status: 2
# Group: 4

# %% [markdown]
# ### Split Data into Training and Testing Sets

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training set shape:", X_train.shape)
print("Testing set shape:", X_test.shape)

print("\nTraining outcomes:")
print(y_train.value_counts())

print("\nTesting outcomes:")
print(y_test.value_counts())
# Out:
# Training set shape: (79592, 238)
# Testing set shape: (19899, 238)
#
# Training outcomes:
# binary_outcome
# 0.0    70113
# 1.0     9479
# Name: count, dtype: int64
#
# Testing outcomes:
# binary_outcome
# 0.0    17529
# 1.0     2370
# Name: count, dtype: int64

# %% [markdown]
# ### Verify Stratification in Train/Test Split

# %%
print("Full Dataset")
print(round(y.value_counts(normalize=True) * 100, 2))

print("\nTraining Dataset")
print(round(y_train.value_counts(normalize=True) * 100, 2))

print("\nTesting Dataset")
print(round(y_test.value_counts(normalize=True) * 100, 2))
# Out:
# Full Dataset
# binary_outcome
# 0.0    88.09
# 1.0    11.91
# Name: proportion, dtype: float64
#
# Training Dataset
# binary_outcome
# 0.0    88.09
# 1.0    11.91
# Name: proportion, dtype: float64
#
# Testing Dataset
# binary_outcome
# 0.0    88.09
# 1.0    11.91
# Name: proportion, dtype: float64

# %% [markdown]
# ### Initialize Logistic Regression Model with Class Weights

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(
    class_weight='balanced',
    max_iter=5000,
    random_state=42
)

# %% [markdown]
# ### Calculate Class Weights Manually (for verification)

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

classes = np.unique(y_train)

weights = compute_class_weight(
    class_weight='balanced',
    classes=classes,
    y=y_train
)

for cls, weight in zip(classes, weights):
    print(f"Class {int(cls)} weight: {weight:.4f}")
# Out:
# Class 0 weight: 0.5676
# Class 1 weight: 4.1983

# %% [markdown]
# ### Train Logistic Regression Model

# %%
log_reg.fit(X_train, y_train)

print("Logistic Regression model trained successfully.")
# Out:
# Logistic Regression model trained successfully.

# %% [markdown]
# ## 4.4.1 Model Evaluation

# %%
y_pred = log_reg.predict(X_test)

y_pred_proba = log_reg.predict_proba(X_test)[:,1]

# %% [markdown]
# ### Calculate Evaluation Metrics

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score
)
import pandas as pd

accuracy = round(accuracy_score(y_test, y_pred),4)
precision = round(precision_score(y_test, y_pred),4)
recall = round(recall_score(y_test, y_pred),4)
f1 = round(f1_score(y_test, y_pred),4)
roc_auc = round(roc_auc_score(y_test, y_pred_proba),4)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("ROC-AUC:", roc_auc)

# Create a DataFrame for the metrics
metrics_df = pd.DataFrame({
    'Metric': ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'ROC-AUC'],
    'Value': [accuracy, precision, recall, f1, roc_auc]
})

# Export to Excel
metrics_df.to_excel("Table_5_Model_Performance_Metrics.xlsx", index=False)

print("\nModel performance metrics exported successfully to 'Table_5_Model_Performance_Metrics.xlsx'.")
# Out:
# Accuracy: 0.969
# Precision: 0.7939
# Recall: 0.9996
# F1 Score: 0.8849
# ROC-AUC: 0.995
#
# Model performance metrics exported successfully to 'Table_5_Model_Performance_Metrics.xlsx'.

# %% [markdown]
# ### Figure 14 Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

cm = confusion_matrix(
    y_test,
    y_pred
)

print(cm)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm
)

disp.plot()

plt.title("Figure 14 Confusion Matrix - Logistic Regression")
plt.savefig(
    'Figure_14_Confusion_Matrix.png',
    dpi=300,
    bbox_inches='tight'
)
print("Figure 14 Confusion Matrix saved to 'Figure_14_Confusion_Matrix.png'.")
plt.show()
# Out:
# [[16914   615]
#  [    1  2369]]
# Figure 14 Confusion Matrix saved to 'Figure_14_Confusion_Matrix.png'.

# %% [markdown]
# ### Figure 15 ROC Curve

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

fpr, tpr, thresholds = roc_curve(
    y_test,
    y_pred_proba
)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.3f}")
plt.plot([0,1],[0,1],'--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Figure 15 ROC Curve - Logistic Regression")
plt.legend()
plt.savefig(
    'Figure_15_ROC_Curve.png',
    dpi=300,
    bbox_inches='tight'
)
print("Figure 15 ROC Curve saved to 'Figure_15_ROC_Curve.png'.")
plt.show()
# Out:
# Figure 15 ROC Curve saved to 'Figure_15_ROC_Curve.png'.

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report

print(
    classification_report(
        y_test,
        y_pred
    )
)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.96      0.98     17529
#          1.0       0.79      1.00      0.88      2370
#
#     accuracy                           0.97     19899
#    macro avg       0.90      0.98      0.93     19899
# weighted avg       0.98      0.97      0.97     19899

# %% [markdown]
# ## 4.4.2 Model Interpretation

# %%
import pandas as pd
import numpy as np

coef_df = pd.DataFrame({
    'Predictor': X_train.columns,
    'Coefficient': log_reg.coef_[0]
})

coef_df['Odds_Ratio'] = np.exp(coef_df['Coefficient'])

coef_df = coef_df.sort_values(
    by='Coefficient',
    ascending=False
)

print("Top 20 Predictors by Coefficient (and Odds Ratio):")
display(coef_df.head(20))
# Out:
# Top 20 Predictors by Coefficient (and Odds Ratio):
#                                              Predictor  Coefficient  \
# 69   Standardized Treatment Name_Eye Movement Desen...     8.122919
# 100  Standardized Treatment Name_MDMA-assisted psyc...     7.931848
# 55   Standardized Treatment Name_Concurrent Treatme...     7.080783
# 219              Clinical Setting_Intensive outpatient     7.013049
# 19             Standardized Treatment Name_Acupuncture     6.717583
# 189  Standardized Treatment Name_Written Exposure T...     6.255921
# 10                               Delivery Method_Mixed     5.567700
# 173  Standardized Treatment Name_Transcendental med...     3.974616
# 201                             Diagnostic Measure_DSM     3.793504
# 194                    Diagnostic Measure_CAPS and DSM     3.229678
# 157                   Standardized Treatment Name_Sham     3.213596
# 38   Standardized Treatment Name_Cognitive Behavior...     3.117915
# 64   Standardized Treatment Name_Emotional Freedom ...     2.751679
# 205                             Diagnostic Measure_PCL     2.629596
# 111  Standardized Treatment Name_Multi-modular moti...     2.481426
# 77   Standardized Treatment Name_Hydrocortisone pri...     2.105387
# 15                 Delivery Method_Technology assisted     2.036131
# 155         Standardized Treatment Name_Seeking Safety     1.981267
# 130  Standardized Treatment Name_Prolonged Exposure...     1.864918
# 57         Standardized Treatment Name_Creating Change     1.726087
#
#       Odds_Ratio
# 69   3370.846808
# 100  2784.568646
# 55   1188.898885
# 219  1111.036367
# 19    826.816266
# 189   521.089203
# 10    261.831309
# 173    53.229649
# 201    44.411744
# 194    25.271525
# 157    24.868345
# 38     22.599213
# 64     15.668920
# 205    13.868169
# 111    11.958304
# 77      8.210282
# 15      7.660909
# 155     7.251926
# 130     6.455409
# 57      5.618624

# %% [markdown]
# ### Top 20 Predictors by Coefficient and Odds Ratio

# %%
print("15 Strongest Positive Predictors (highest coefficients):")
display(coef_df.sort_values(
    by='Coefficient',
    ascending=False
).head(15))
# Out:
# 15 Strongest Positive Predictors (highest coefficients):
#                                              Predictor  Coefficient  \
# 69   Standardized Treatment Name_Eye Movement Desen...     8.122919
# 100  Standardized Treatment Name_MDMA-assisted psyc...     7.931848
# 55   Standardized Treatment Name_Concurrent Treatme...     7.080783
# 219              Clinical Setting_Intensive outpatient     7.013049
# 19             Standardized Treatment Name_Acupuncture     6.717583
# 189  Standardized Treatment Name_Written Exposure T...     6.255921
# 10                               Delivery Method_Mixed     5.567700
# 173  Standardized Treatment Name_Transcendental med...     3.974616
# 201                             Diagnostic Measure_DSM     3.793504
# 194                    Diagnostic Measure_CAPS and DSM     3.229678
# 157                   Standardized Treatment Name_Sham     3.213596
# 38   Standardized Treatment Name_Cognitive Behavior...     3.117915
# 64   Standardized Treatment Name_Emotional Freedom ...     2.751679
# 205                             Diagnostic Measure_PCL     2.629596
# 111  Standardized Treatment Name_Multi-modular moti...     2.481426
#
#       Odds_Ratio
# 69   3370.846808
# 100  2784.568646
# 55   1188.898885
# 219  1111.036367
# 19    826.816266
# 189   521.089203
# 10    261.831309
# 173    53.229649
# 201    44.411744
# 194    25.271525
# 157    24.868345
# 38     22.599213
# 64     15.668920
# 205    13.868169
# 111    11.958304

# %% [markdown]
# ### 15 Strongest Positive Predictors

# %%
print("15 Strongest Negative Predictors (lowest coefficients):")
display(coef_df.sort_values(
    by='Coefficient',
    ascending=True
).head(15))
# Out:
# 15 Strongest Negative Predictors (lowest coefficients):
#                                              Predictor  Coefficient  \
# 215                         Diagnostic Measure_SI-PTSD    -3.781878
# 147     Standardized Treatment Name_Relapse Prevention    -3.318631
# 196                   Diagnostic Measure_CAPS and MINI    -3.030945
# 106  Standardized Treatment Name_Mindfulness-based ...    -2.853236
# 187               Standardized Treatment Name_Waitlist    -2.639268
# 75   Standardized Treatment Name_High Delta-9-tetra...    -2.345067
# 110  Standardized Treatment Name_Multi-modular moti...    -2.256825
# 179  Standardized Treatment Name_Treatment as usual...    -2.250330
# 220                             Clinical Setting_Mixed    -2.228911
# 141          Standardized Treatment Name_Psychotherapy    -2.160863
# 32             Standardized Treatment Name_Brofaromine    -2.060256
# 30   Standardized Treatment Name_Biofeedback-assist...    -2.044379
# 5                                      Trauma Type_MST    -2.025734
# 66                Standardized Treatment Name_Exercise    -1.986025
# 128  Standardized Treatment Name_Present-Centered T...    -1.926414
#
#      Odds_Ratio
# 215    0.022780
# 147    0.036202
# 196    0.048270
# 106    0.057657
# 187    0.071413
# 75     0.095841
# 110    0.104682
# 179    0.105364
# 220    0.107646
# 141    0.115226
# 32     0.127421
# 30     0.129461
# 5      0.131897
# 66     0.137240
# 128    0.145670

# %% [markdown]
# ### 15 Strongest Negative Predictors

# %%
import statsmodels.api as sm

# 1. Define the list of corrected reduced predictors
# Exclude 'Trauma Type_MST' and 'Trauma Type_Other'

# Start with continuous variables
reduced_predictors_corrected = [
    'Veteran Percent',
    'Female Percent',
    'baseline_z',
    'treatment_duration'
]

# Add 'Trauma Type_' columns, excluding the problematic ones
trauma_type_cols_corrected = [
    col for col in X_train.columns if col.startswith('Trauma Type_')
    and col not in ['Trauma Type_MST', 'Trauma Type_Other']
]
reduced_predictors_corrected.extend(trauma_type_cols_corrected)

# 2. Create the new DataFrame X_train_reduced_corrected
X_train_reduced_corrected = X_train[reduced_predictors_corrected].copy()

# 3. Add a constant to X_train_reduced_corrected for statsmodels
X_train_reduced_sm_corrected = sm.add_constant(X_train_reduced_corrected)

print("Corrected reduced predictors defined:")
print(reduced_predictors_corrected)
print("Shape of X_train_reduced_sm_corrected:", X_train_reduced_sm_corrected.shape)
print("Columns in X_train_reduced_sm_corrected:", X_train_reduced_sm_corrected.columns.tolist())
# Out:
# Corrected reduced predictors defined:
# ['Veteran Percent', 'Female Percent', 'baseline_z', 'treatment_duration', 'Trauma Type_Combat-related', 'Trauma Type_Mixed']
# Shape of X_train_reduced_sm_corrected: (79592, 7)
# Columns in X_train_reduced_sm_corrected: ['const', 'Veteran Percent', 'Female Percent', 'baseline_z', 'treatment_duration', 'Trauma Type_Combat-related', 'Trauma Type_Mixed']

# %% [markdown]
# ### Convert Boolean Columns to Integers for Statsmodels

# %%
print('Original dtypes of X_train_reduced_sm_corrected:')
print(X_train_reduced_sm_corrected.dtypes)

# Convert boolean columns to integer type (0 or 1)
for col in X_train_reduced_sm_corrected.columns:
    if X_train_reduced_sm_corrected[col].dtype == 'bool':
        X_train_reduced_sm_corrected[col] = X_train_reduced_sm_corrected[col].astype(int)

print('\nCorrected dtypes of X_train_reduced_sm_corrected:')
print(X_train_reduced_sm_corrected.dtypes)
# Out:
# Original dtypes of X_train_reduced_sm_corrected:
# const                         float64
# Veteran Percent               float64
# Female Percent                float64
# baseline_z                    float64
# treatment_duration            float64
# Trauma Type_Combat-related       bool
# Trauma Type_Mixed                bool
# dtype: object
#
# Corrected dtypes of X_train_reduced_sm_corrected:
# const                         float64
# Veteran Percent               float64
# Female Percent                float64
# baseline_z                    float64
# treatment_duration            float64
# Trauma Type_Combat-related      int64
# Trauma Type_Mixed               int64
# dtype: object

# %% [markdown]
# ### Fit Reduced Logistic Regression Model using Statsmodels

# %%
logit_model_reduced_corrected = sm.Logit(y_train, X_train_reduced_sm_corrected)
logit_model_reduced_corrected_result = logit_model_reduced_corrected.fit(maxiter=1000, disp=False)

print("Corrected reduced Logit model fitted successfully.")
# Out:
# Corrected reduced Logit model fitted successfully.

# %% [markdown]
# ### Display Coefficients and Odds Ratios for Reduced Model

# %%
import numpy as np

# Get the coefficients from the fitted model
coefficients = logit_model_reduced_corrected_result.params

# Calculate the odds ratios by exponentiating the coefficients
odds_ratios = np.exp(coefficients)

# Create a DataFrame to display coefficients and odds ratios
odds_ratios_df = pd.DataFrame({
    'Predictor': coefficients.index,
    'Coefficient': coefficients.values,
    'Odds_Ratio': odds_ratios.values
})

# Sort by Odds Ratio for better readability
odds_ratios_df = odds_ratios_df.sort_values(by='Odds_Ratio', ascending=False)

print("Coefficients and Odds Ratios from the corrected reduced Logit model:")
display(odds_ratios_df)
# Out:
# Coefficients and Odds Ratios from the corrected reduced Logit model:
#                     Predictor  Coefficient  Odds_Ratio
# 6           Trauma Type_Mixed     2.700018   14.879996
# 5  Trauma Type_Combat-related     1.857096    6.405112
# 1             Veteran Percent     0.018964    1.019145
# 4          treatment_duration    -0.011395    0.988669
# 2              Female Percent    -0.013871    0.986225
# 3                  baseline_z    -1.761145    0.171848
# 0                       const    -5.747352    0.003191

# %% [markdown]
# ### Display Full Summary of Reduced Logit Model

# %%
print(logit_model_reduced_corrected_result.summary())
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         binary_outcome   No. Observations:                79592
# Model:                          Logit   Df Residuals:                    79585
# Method:                           MLE   Df Model:                            6
# Date:                Wed, 12 Aug 2026   Pseudo R-squ.:                  0.3064
# Time:                        22:51:33   Log-Likelihood:                -20158.
# converged:                       True   LL-Null:                       -29060.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -5.7474      0.237    -24.283      0.000      -6.211      -5.283
# Veteran Percent                0.0190      0.002     12.603      0.000       0.016       0.022
# Female Percent                -0.0139      0.001    -18.266      0.000      -0.015      -0.012
# baseline_z                    -1.7611      0.019    -94.819      0.000      -1.798      -1.725
# treatment_duration            -0.0114      0.005     -2.280      0.023      -0.021      -0.002
# Trauma Type_Combat-related     1.8571      0.183     10.171      0.000       1.499       2.215
# Trauma Type_Mixed              2.7000      0.178     15.195      0.000       2.352       3.048
# ==============================================================================================

# %% [markdown]
# ### Create Dissertation Table 6

# %%
import pandas as pd
import numpy as np

# Extract coefficients, p-values, and odds ratios
coefficients = logit_model_reduced_corrected_result.params
p_values = logit_model_reduced_corrected_result.pvalues

odds_ratios = np.exp(coefficients)

# Create the DataFrame for the table
table_data = pd.DataFrame({
    'Predictor': coefficients.index,
    'Coefficient': coefficients.values,
    'Odds Ratio': odds_ratios.values,
    'p-value': p_values.values
})

# Format p-values as '<0.001' or actual value
table_data['p-value'] = table_data['p-value'].apply(lambda x: '<0.001' if x < 0.001 else round(x, 3))

# Sort for better readability, similar to the example
table_data = table_data.sort_values(by='Coefficient', ascending=False).reset_index(drop=True)

# Display the table
print("Dissertation Table 6: Logistic Regression Coefficients, Odds Ratios, and P-values")
display(table_data)
# Out:
# Dissertation Table 6: Logistic Regression Coefficients, Odds Ratios, and P-values
#                     Predictor  Coefficient  Odds Ratio p-value
# 0           Trauma Type_Mixed     2.700018   14.879996  <0.001
# 1  Trauma Type_Combat-related     1.857096    6.405112  <0.001
# 2             Veteran Percent     0.018964    1.019145  <0.001
# 3          treatment_duration    -0.011395    0.988669   0.023
# 4              Female Percent    -0.013871    0.986225  <0.001
# 5                  baseline_z    -1.761145    0.171848  <0.001
# 6                       const    -5.747352    0.003191  <0.001

# %% [markdown]
# ### Export Dissertation Table 6

# %%
table_data.to_excel(
    "Table_6_Logistic_Regression_Results.xlsx",
    index=False
)

print("Dissertation Table 6 exported successfully to 'Table_6_Logistic_Regression_Results.xlsx'.")
# Out:
# Dissertation Table 6 exported successfully to 'Table_6_Logistic_Regression_Results.xlsx'.

# %% [markdown]
# ### Figure 16 Odds Ratios of Reduced Model Predictors

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Exclude the 'const' variable for plotting as it's an intercept term
odds_ratios_to_plot = odds_ratios_df[odds_ratios_df['Predictor'] != 'const'].copy()

# Sort by Odds Ratio for plotting
odds_ratios_to_plot = odds_ratios_to_plot.sort_values(by='Odds_Ratio', ascending=True)

# Create a color map for visualization: blue for odds ratio > 1 (increased odds), red for < 1 (decreased odds)
odds_ratios_to_plot['color'] = odds_ratios_to_plot['Odds_Ratio'].apply(lambda x: 'skyblue' if x > 1 else 'lightcoral')

# Visualize the odds ratios
plt.figure(figsize=(12, 8))
sns.barplot(
    x='Odds_Ratio',
    y='Predictor',
    hue='Predictor', # Assign 'Predictor' to hue for coloring
    data=odds_ratios_to_plot,
    palette=odds_ratios_to_plot['color'].tolist(),
    legend=False # Set legend to False to avoid duplicate legend
)
plt.title('Figure 16 Odds Ratios of Predictors')
plt.xlabel('Odds Ratio (exp(Coefficient))')
plt.ylabel('Predictor')
plt.axvline(x=1, color='gray', linestyle='--', linewidth=0.8, label='Odds Ratio = 1 (No Effect)')
plt.legend()
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig(
    'Figure_16_Odds_Ratios.png',
    dpi=300,
    bbox_inches='tight'
)
print("Figure 16 Odds Ratios Plot saved to 'Figure_16_Odds_Ratios.png'.")
plt.show()
# Out:
# Figure 16 Odds Ratios Plot saved to 'Figure_16_Odds_Ratios.png'.

# %% [markdown]
# ## 4.5 Calibration Analysis

# %%
from sklearn.calibration import calibration_curve
import matplotlib.pyplot as plt

prob_true, prob_pred = calibration_curve(
    y_test,
    y_pred_proba,
    n_bins=10
)

plt.figure(figsize=(8,6))

plt.plot(
    prob_pred,
    prob_true,
    marker='o',
    label='Logistic Regression'
)

plt.plot(
    [0,1],
    [0,1],
    linestyle='--',
    label='Perfect Calibration'
)

plt.xlabel('Predicted Probability')
plt.ylabel('Observed Proportion')

plt.title('Figure 17 Calibration Curve')

plt.legend()

plt.savefig(
    'Figure_17_Calibration_Curve.png',
    dpi=300,
    bbox_inches='tight'
)

print("Figure 17 Calibration Curve saved to 'Figure_17_Calibration_Curve.png'.")

plt.show()
# Out:
# Figure 17 Calibration Curve saved to 'Figure_17_Calibration_Curve.png'.

# %% [markdown]
# ### Brier Score

# %%
from sklearn.metrics import brier_score_loss

brier = brier_score_loss(
    y_test,
    y_pred_proba
)

print("Brier Score:", round(brier,4))
# Out:
# Brier Score: 0.0244

# %% [markdown]
# ### Calibration Intercept and Slope

# %%
import numpy as np
import statsmodels.api as sm

# Convert predicted probabilities to log-odds (logits)
logit_pred = np.log(
    y_pred_proba / (1 - y_pred_proba)
)

# Fit a logistic regression model with the true outcomes and predicted log-odds
calibration_model = sm.Logit(
    y_test,
    sm.add_constant(logit_pred) # Add a constant for the intercept
).fit(disp=False) # disp=False suppresses iteration details

print(calibration_model.summary())

# Extract the intercept and slope
intercept = calibration_model.params[0]
slope = calibration_model.params[1]

print("\nCalibration Intercept:", round(intercept, 4))
print("Calibration Slope:", round(slope, 4))
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         binary_outcome   No. Observations:                19899
# Model:                          Logit   Df Residuals:                    19897
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 12 Aug 2026   Pseudo R-squ.:                  0.8758
# Time:                        22:51:33   Log-Likelihood:                -902.64
# converged:                       True   LL-Null:                       -7265.7
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.5873      0.230    -11.229      0.000      -3.039      -2.136
# x1             1.3520      0.112     12.088      0.000       1.133       1.571
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.82 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
#
# Calibration Intercept: -2.5873
# Calibration Slope: 1.352
# /tmp/ipykernel_1349/2602956573.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept = calibration_model.params[0]
# /tmp/ipykernel_1349/2602956573.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   slope = calibration_model.params[1]

# %% [markdown]
# ### Verify Columns for Calibration Analysis (Redundant Check)

# %%
print('Percent Achieved Diagnostic Change' in X.columns)
print('binary_outcome' in X.columns)
# Out:
# False
# False

# %% [markdown]
# ### Table 7: Calibration Measures

# %%
table_7 = pd.DataFrame({
    'Measure': [
        'Calibration Slope',
        'Calibration Intercept',
        'Brier Score'
    ],
    'Value': [
        round(slope, 4),
        round(intercept, 4),
        round(brier, 4)
    ]
})
display(table_7)
# Out:
#                  Measure   Value
# 0      Calibration Slope  1.3520
# 1  Calibration Intercept -2.5873
# 2            Brier Score  0.0244

# %% [markdown]
# ### Export Dissertation Table 7

# %%
table_7.to_excel(
    "Table_7_Calibration_Measures.xlsx",
    index=False
)
print("Table 7 exported successfully to 'Table_7_Calibration_Measures.xlsx'.")
# Out:
# Table 7 exported successfully to 'Table_7_Calibration_Measures.xlsx'.

# %% [markdown]
# ### Identify Columns Containing 'score', 'change', 'difference', 'effect'

# %%
for col in df.columns:
    if 'score' in col.lower() or 'change' in col.lower() or 'difference' in col.lower() or 'effect' in col.lower():
        print(col)
# Out:
# Percent Achieved Diagnostic Change
# Standardized Treatment Name_Creating Change

# %% [markdown]
# ### Linear Regression Features and Target

# %% [markdown]
# ## 4.6 Linear Regression Model Development

# %%
X_linear = X.copy()
y_linear = df['Percent Achieved Diagnostic Change']

print("X_linear shape:", X_linear.shape)
print("y_linear shape:", y_linear.shape)
# Out:
# X_linear shape: (99491, 238)
# y_linear shape: (99491,)

# %% [markdown]
# ### Data Split for Linear Regression

# %%
from sklearn.model_selection import train_test_split

X_train_lr, X_test_lr, y_train_lr, y_test_lr = train_test_split(
    X_linear,
    y_linear,
    test_size=0.20,
    random_state=42
)

print("Training set shape:", X_train_lr.shape)
print("Testing set shape:", X_test_lr.shape)
# Out:
# Training set shape: (79592, 238)
# Testing set shape: (19899, 238)

# %% [markdown]
# ### Linear Regression Model Training

# %%
### Linear Regression Model Predictions

# %% [markdown]
# ### Make Predictions with Linear Regression Model

# %%
y_pred_lr = lin_reg.predict(X_test_lr)

# %% [markdown]
# ### Linear Regression Model Performance Metrics

# %%
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

import numpy as np

r2 = r2_score(y_test_lr, y_pred_lr)

mae = mean_absolute_error(
    y_test_lr,
    y_pred_lr
)

rmse = np.sqrt(
    mean_squared_error(
        y_test_lr,
        y_pred_lr
    )
)

print("R²:", round(r2,4))
print("MAE:", round(mae,4))
print("RMSE:", round(rmse,4))

# Create a DataFrame for the metrics
table_8 = pd.DataFrame({
    'Metric': ['R²', 'MAE', 'RMSE'],
    'Value': [round(r2, 4), round(mae, 4), round(rmse, 4)]
})

# Display and export to Excel
display(table_8)

table_8.to_excel(
    "Table_8_Linear_Regression_Performance.xlsx",
    index=False
)

print("Table 8 exported successfully to 'Table_8_Linear_Regression_Performance.xlsx'.")
# Out:
# R²: 0.9136
# MAE: 1.8192
# RMSE: 3.3975
#   Metric   Value
# 0     R²  0.9136
# 1    MAE  1.8192
# 2   RMSE  3.3975
# Table 8 exported successfully to 'Table_8_Linear_Regression_Performance.xlsx'.

# %% [markdown]
# ### Figure 18 Residual Plot

# %%
import matplotlib.pyplot as plt

residuals = y_test_lr - y_pred_lr

plt.figure(figsize=(8,6))

plt.scatter(
    y_pred_lr,
    residuals,
    alpha=0.5
)

plt.axhline(
    y=0,
    linestyle='--',
    color='red'
)

plt.xlabel("Predicted Values")
plt.ylabel("Residuals")

plt.title("Figure 18 Residual Plot - Linear Regression")

plt.savefig(
    'Figure_18_Residual_Plot.png',
    dpi=300,
    bbox_inches='tight'
)

print("Figure 18 Residual Plot saved to 'Figure_18_Residual_Plot.png'.")
plt.show()
# Out:
# Figure 18 Residual Plot saved to 'Figure_18_Residual_Plot.png'.

# %% [markdown]
# ### Figure 19 Q-Q Plot of Residuals

# %%
import matplotlib.pyplot as plt
import scipy.stats as stats

plt.figure(figsize=(8,6))

stats.probplot(
    residuals,
    dist="norm",
    plot=plt
)

plt.title("Figure 19 Q-Q Plot of Linear Regression Residuals")
plt.savefig(
    'Figure_19_QQ_Plot.png',
    dpi=300,
    bbox_inches='tight'
)
print("Figure 19 Q-Q Plot saved to 'Figure_19_QQ_Plot.png'.")
plt.show()
# Out:
# Figure 19 Q-Q Plot saved to 'Figure_19_QQ_Plot.png'.

# %% [markdown]
# ### Top Linear Regression Coefficients

# %%
coef_df_lr = pd.DataFrame({
    'Predictor': X_linear.columns,
    'Coefficient': lin_reg.coef_
})

coef_df_lr = coef_df_lr.sort_values(
    by='Coefficient',
    ascending=False
)

print("Linear Regression Coefficients (Top 20):")
display(coef_df_lr.head(20))
# Out:
# Linear Regression Coefficients (Top 20):
#                                              Predictor  Coefficient
# 64   Standardized Treatment Name_Emotional Freedom ...    61.711063
# 178     Standardized Treatment Name_Treatment as usual    41.089124
# 69   Standardized Treatment Name_Eye Movement Desen...    35.648566
# 15                 Delivery Method_Technology assisted    27.506880
# 12                    Delivery Method_Technology Alone    26.568466
# 9                            Delivery Method_In person    26.023372
# 55   Standardized Treatment Name_Concurrent Treatme...    25.751846
# 14                    Delivery Method_Technology alone    24.209093
# 120   Standardized Treatment Name_Paroxetine + placebo    23.813259
# 10                               Delivery Method_Mixed    22.106606
# 100  Standardized Treatment Name_MDMA-assisted psyc...    21.575008
# 195                    Diagnostic Measure_CAPS and ITQ    21.569477
# 19             Standardized Treatment Name_Acupuncture    21.233576
# 157                   Standardized Treatment Name_Sham    19.224584
# 77   Standardized Treatment Name_Hydrocortisone pri...    18.298833
# 116  Standardized Treatment Name_PTSD Family Education    17.817029
# 186  Standardized Treatment Name_Virtual reality ex...    17.320474
# 150  Standardized Treatment Name_Relaxation with de...    17.320057
# 59   Standardized Treatment Name_Desipramine + nalt...    17.212912
# 13                 Delivery Method_Technology Assisted    16.970681

# %% [markdown]
# ### Reduced Features for Linear Regression (OLS)

# %%
linear_vars = [
    'Veteran Percent',
    'Female Percent',
    'baseline_z',
    'treatment_duration',
    'Trauma Type_Combat-related',
    'Trauma Type_Mixed'
]

X_linear_reduced = df[linear_vars]

y_linear = df['Percent Achieved Diagnostic Change']

print("X_linear_reduced shape:", X_linear_reduced.shape)
print("y_linear shape:", y_linear.shape)
# Out:
# X_linear_reduced shape: (99491, 6)
# y_linear shape: (99491,)

# %% [markdown]
# ### Reduced Linear Regression Model Training (OLS)

# %%
import statsmodels.api as sm

# Create a copy to avoid SettingWithCopyWarning
X_linear_reduced_copy = X_linear_reduced.copy()

# Ensure boolean columns are converted to int for statsmodels
for col in X_linear_reduced_copy.columns:
    if X_linear_reduced_copy[col].dtype == 'bool':
        X_linear_reduced_copy.loc[:, col] = X_linear_reduced_copy[col].astype(int)

X_linear_reduced_sm = sm.add_constant(X_linear_reduced_copy)

ols_model = sm.OLS(
    y_linear,
    X_linear_reduced_sm
).fit()

print(ols_model.summary())
# Out:
#                                     OLS Regression Results
# ==============================================================================================
# Dep. Variable:     Percent Achieved Diagnostic Change   R-squared:                       0.084
# Model:                                            OLS   Adj. R-squared:                  0.084
# Method:                                 Least Squares   F-statistic:                     1517.
# Date:                                Wed, 12 Aug 2026   Prob (F-statistic):               0.00
# Time:                                        22:59:57   Log-Likelihood:            -3.8114e+05
# No. Observations:                               99491   AIC:                         7.623e+05
# Df Residuals:                                   99484   BIC:                         7.624e+05
# Df Model:                                           6
# Covariance Type:                            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         28.3031      0.306     92.476      0.000      27.703      28.903
# Veteran Percent                0.0262      0.003     10.250      0.000       0.021       0.031
# Female Percent                -0.0109      0.001     -8.213      0.000      -0.014      -0.008
# baseline_z                    -3.0896      0.036    -85.635      0.000      -3.160      -3.019
# treatment_duration            -0.1019      0.013     -7.760      0.000      -0.128      -0.076
# Trauma Type_Combat-related     7.8774      0.210     37.520      0.000       7.466       8.289
# Trauma Type_Mixed              6.0728      0.189     32.143      0.000       5.702       6.443
# ==============================================================================
# Omnibus:                    24518.261   Durbin-Watson:                   0.262
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            99975.063
# Skew:                           1.172   Prob(JB):                         0.00
# Kurtosis:                       7.316   Cond. No.                     1.04e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.04e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /tmp/ipykernel_1349/4041272147.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0 0 0 ... 0 0 0]' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   X_linear_reduced_copy.loc[:, col] = X_linear_reduced_copy[col].astype(int)
# /tmp/ipykernel_1349/4041272147.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0 0 0 ... 1 1 1]' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   X_linear_reduced_copy.loc[:, col] = X_linear_reduced_copy[col].astype(int)

# %% [markdown]
# ### Reduced OLS Model Coefficients, Standard Errors, and P-values

# %%
results_table = pd.DataFrame({
    'Predictor': ols_model.params.index,
    'Coefficient': ols_model.params.values,
    'Standard Error': ols_model.bse.values,
    'p-value': ols_model.pvalues.values
})

# Format p-values as '<0.001' or actual value
results_table['p-value'] = results_table['p-value'].apply(lambda x: '<0.001' if x < 0.001 else round(x, 3))

display(results_table)
# Out:
#                     Predictor  Coefficient  Standard Error p-value
# 0                       const    28.303131        0.306060  <0.001
# 1             Veteran Percent     0.026190        0.002555  <0.001
# 2              Female Percent    -0.010904        0.001328  <0.001
# 3                  baseline_z    -3.089580        0.036078  <0.001
# 4          treatment_duration    -0.101864        0.013126  <0.001
# 5  Trauma Type_Combat-related     7.877399        0.209954  <0.001
# 6           Trauma Type_Mixed     6.072760        0.188928  <0.001

# %% [markdown]
# ### Table 9 Export

# %%
results_table.to_excel(
    "Table_9_Linear_Regression_Coefficients.xlsx",
    index=False
)

print("Table 9 exported successfully to 'Table_9_Linear_Regression_Coefficients.xlsx'.")
# Out:
# Table 9 exported successfully to 'Table_9_Linear_Regression_Coefficients.xlsx'.

# %% [markdown]
# ### Variance Inflation Factor (VIF) for Reduced Model

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Calculate VIF for each predictor in X_linear_reduced_sm
vif_data = pd.DataFrame()
vif_data['Predictor'] = X_linear_reduced_sm.columns
vif_data['VIF'] = [variance_inflation_factor(X_linear_reduced_sm.values, i) for i in range(X_linear_reduced_sm.shape[1])]

# Sort the DataFrame by VIF values in descending order for easier interpretation
vif_data = vif_data.sort_values(by='VIF', ascending=False).reset_index(drop=True)

print("Variance Inflation Factor (VIF) for Predictors in Reduced Linear Regression Model:")
display(vif_data)
# Out:
# Variance Inflation Factor (VIF) for Predictors in Reduced Linear Regression Model:
#                     Predictor        VIF
# 0                       const  74.884843
# 1  Trauma Type_Combat-related   6.940412
# 2           Trauma Type_Mixed   6.068183
# 3          treatment_duration   1.546106
# 4              Female Percent   1.278651
# 5                  baseline_z   1.230551
# 6             Veteran Percent   1.117166

# %% [markdown]
# ### Table 10 Export

# %%
vif_data.to_excel(
    "Table_10_VIF_Results.xlsx",
    index=False
)

print("Variance Inflation Factor (VIF) results exported successfully to 'Table_10_VIF_Results.xlsx'.")
# Out:
# Variance Inflation Factor (VIF) results exported successfully to 'Table_10_VIF_Results.xlsx'.

# %% [markdown]
# ## 4.7 Decision Curve Analysis (DCA)

# %%
import numpy as np
import pandas as pd

thresholds = np.arange(0.01, 0.99, 0.01)

net_benefits = []

N = len(y_test)

for pt in thresholds:

    predictions = (y_pred_proba >= pt).astype(int)

    TP = ((predictions == 1) & (y_test == 1)).sum()
    FP = ((predictions == 1) & (y_test == 0)).sum()

    # Calculate Net Benefit (NB)
    # The formula is: NB = (TP / N) - (FP / N) * (pt / (1 - pt))
    # Where pt is the threshold probability (or probability of treatment)
    # and pt / (1 - pt) is the odds of harm (relative weight of false positives)
    nb = (TP / N) - (FP / N) * (pt / (1 - pt))

    net_benefits.append(nb)

dca_results = pd.DataFrame({
    'Threshold Probability': thresholds,
    'Net Benefit': net_benefits
})

print("Net Benefit values for the Prediction Model calculated.")
display(dca_results.head())
# Out:
# Net Benefit values for the Prediction Model calculated.
#    Threshold Probability  Net Benefit
# 0                   0.01     0.118500
# 1                   0.02     0.118270
# 2                   0.03     0.117898
# 3                   0.04     0.117529
# 4                   0.05     0.117163

# %% [markdown]
# ### Net Benefit for Prediction Model

# %%
prevalence = y_test.mean()

treat_all_nb = []

for pt in thresholds:
    # Net benefit for treating all individuals
    # NB_all = prevalence - (1 - prevalence) * (pt / (1 - pt))
    nb_all = prevalence - (1 - prevalence) * (pt / (1 - pt))
    treat_all_nb.append(nb_all)

print("Net Benefit values for 'Treat All' strategy calculated.")
# Out:
# Net Benefit values for 'Treat All' strategy calculated.

# %% [markdown]
# ### Net Benefit for 'Treat All' Strategy

# %%
### Net Benefit for 'Treat None' Strategy

# %% [markdown]
# ### Net Benefit for 'Treat None' Strategy

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,7))

plt.plot(
    thresholds,
    net_benefits,
    label='Prediction Model',
    linewidth=2
)

plt.plot(
    thresholds,
    treat_all_nb,
    linestyle='--',
    label='Treat All'
)

plt.plot(
    thresholds,
    treat_none_nb,
    linestyle=':',
    label='Treat None'
)

plt.xlabel('Threshold Probability')

plt.ylabel('Net Benefit')

plt.title('Figure 20 Decision Curve Analysis (Enhanced)')

plt.legend()

plt.grid(True)

# --- FIX: Set clinically relevant axis limits ---
plt.xlim(0.0, 0.5) # Limit X-axis to 0% to 50% risk threshold
plt.ylim(-0.02, prevalence + 0.05) # Zoom Y-axis around the prevalence rate
# -------------------------------------------------

plt.savefig(
    'Figure_20_Decision_Curve_Analysis_Enhanced.png',
    dpi=300,
    bbox_inches='tight'
)

print("Figure 20 Decision Curve Analysis Plot (Enhanced) saved to 'Figure_20_Decision_Curve_Analysis_Enhanced.png'.")
plt.show()
# Out:
# Figure 20 Decision Curve Analysis Plot (Enhanced) saved to 'Figure_20_Decision_Curve_Analysis_Enhanced.png'.

# %% [markdown]
# ### Table 11: DCA Results for Selected Thresholds

# %%
selected_thresholds = [0.10, 0.20, 0.30, 0.40, 0.50]

table_11 = dca_results[
    dca_results['Threshold Probability'].round(2).isin(selected_thresholds)
].copy()

print("Table 11 created for selected thresholds:")
display(table_11)
# Out:
# Table 11 created for selected thresholds:
#     Threshold Probability  Net Benefit
# 9                     0.1     0.115327
# 19                    0.2     0.111023
# 29                    0.3     0.105590
# 39                    0.4     0.098414
# 49                    0.5     0.088145

# %% [markdown]
# ### Table 11 Export

# %%
table_11.to_excel(
    "Table_11_DCA_Results.xlsx",
    index=False
)

print("Table 11 exported successfully to 'Table_11_DCA_Results.xlsx'.")
# Out:
# Table 11 exported successfully to 'Table_11_DCA_Results.xlsx'.
